# %% [markdown]
# ### **Load libraries**

# %%
import sys
sys.path.append('../src')
import pandas as pd
import numpy as np
import ipywidgets as widgets
from IPython.display import display
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import risk_kit as rk
import importlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# ### **Define ticker names**

# %%
col_stock_list_path = 'colombia_stocks_trii.csv'
global_stock_list_path = 'global_stocks_trii.csv'

ticker_list_col = list(pd.read_csv(col_stock_list_path, header=None)[0])
ticker_list_glob = list(pd.read_csv(global_stock_list_path, header=None)[0])

# %%
""" Alt method
col_stock_list_path = 'colombia_stocks_trii.csv'
global_stock_list_path = 'global_stocks_trii.csv'

with open(col_stock_list_path) as s:
    ticker_list_col = []
    [ticker_list_col.append(l.replace('\n', '')) for l in s]
    s.close()
with open(global_stock_list_path) as s:
    ticker_list_global = []
    [ticker_list_global.append(l.replace('\n', '')) for l in s]
    s.close()
"""
# Out:
# " Alt method\ncol_stock_list_path = 'colombia_stocks_trii.csv'\nglobal_stock_list_path = 'global_stocks_trii.csv'\n\nwith open(col_stock_list_path) as s:\n    ticker_list_col = []\n    [ticker_list_col.append(l.replace('\n', '')) for l in s]\n    s.close()\nwith open(global_stock_list_path) as s:\n    ticker_list_global = []\n    [ticker_list_global.append(l.replace('\n', '')) for l in s]\n    s.close()\n"

# %%
# Define the number of periods per year for all calculations
# 252 is an approximation for daily
# 54 for weekly
# 12 for monthly
periods_per_year = 54

# %% [markdown]
# ### **Extract data from YFinance**

# %%
days_of_data = 365*10
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=days_of_data)

# %%
#interval = '1d'   # Uncomment for daily data
interval = '1wk'  # Uncomment for weekly data
# interval = '1mo' # Uncomment for monthly data

col_stocks_raw = yf.download(ticker_list_col, interval=interval, start=start_date, end=end_date, auto_adjust=True)['Close']
global_stocks_raw = yf.download(ticker_list_glob, interval=interval, start=start_date, end=end_date, auto_adjust=True)['Close']
# Out:
# [*********************100%***********************]  37 of 37 completed
# [*********************100%***********************]  87 of 87 completed
#
# 3 Failed downloads:
# ['IWVLM.XD', 'EQACM.XD', '4BRZD.XD']: YFPricesMissingError('possibly delisted; no price data found  (1wk 2015-12-12 -> 2025-12-09)')

# %% [markdown]
# ### **Preprocessing**

# %%
# Assign a frequency to the index of the dataframes
# col_stocks_raw.index = col_stocks_raw.index.to_period(freq='D') # Uncomment to set frequency as Daily
# global_stocks_raw.index = global_stocks_raw.index.to_period(freq='D') # Uncomment to set ferquency as Daily

col_stocks_raw.index = col_stocks_raw.index.to_period(freq='W') # Uncomment to set frequency as Weekly
global_stocks_raw.index = global_stocks_raw.index.to_period(freq='W') # Uncomment to set ferquency as Weekly

# col_stocks_raw.index = col_stocks_raw.index.to_period(freq='M') # Uncomment to set frequency as Monthly
# global_stocks_raw.index = global_stocks_raw.index.to_period(freq='M') # Uncomment to set frequency as Monthly

# %%
def combine_duplicate_rows(df):
    """
    Fix for new issue where YFinance returns duplicate records for the latest week.
    """
    def first_non_null(series):
        """Return the first non-null value in the series"""
        non_null = series.dropna()
        if len(non_null) > 0:
            return non_null.iloc[0]
        return np.nan
    
    grouped = df.groupby(df.index)
    result = grouped.agg(first_non_null)
    return result

# %%
col_stocks_raw = combine_duplicate_rows(col_stocks_raw)
global_stocks_raw = combine_duplicate_rows(global_stocks_raw)

# %%
# Merge Col and Global stock prices and returns data
stocks = pd.concat([col_stocks_raw, global_stocks_raw], axis='columns').sort_index()

# %%
stocks_not_missing = stocks.columns[stocks.isna().sum() < stocks.shape[0]*.15]

# %%
# For days without stock price info, assume the stock price is the same of the previous day
stocks = stocks[stocks_not_missing].fillna(method='bfill')

# Convert from stock prices into returns
rets = stocks.pct_change().iloc[1:]
# Out:
# C:\Users\jumar\AppData\Local\Temp\ipykernel_6372\3483962844.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   stocks = stocks[stocks_not_missing].fillna(method='bfill')
# C:\Users\jumar\AppData\Local\Temp\ipykernel_6372\3483962844.py:5: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   rets = stocks.pct_change().iloc[1:]

# %%
# Define start and end dates of the analysis
days_of_analysis = 365*10   # 5 years
end_date = str(datetime.date.today())
start_date = str(datetime.date.today() - datetime.timedelta(days=days_of_analysis))

# %%
rets = rets.loc[start_date:end_date]
stocks = stocks.loc[start_date:end_date]

# %%
(rets.shape, stocks.shape)
# Out:
# ((522, 79), (523, 79))

# %% [markdown]
# ### **Initial examination**

# %%
df1_to_plot = rets
df2_to_plot = (stocks - stocks.min()) / (stocks.max() - stocks.min())

fig, axes = plt.subplots(2, 1, figsize=(12, 10))
df1_to_plot.plot(ax = axes[0], legend=False)
df2_to_plot.plot(ax=axes[1], legend=False)
plt.tight_layout()

# %%
summary_stats = rk.summary_stats(rets, riskfree_rate=0, periods_per_year=periods_per_year)
summary_stats
# Out:
#                Annualized Return  Annualized Volatility   Skewness  \
# Ticker
# BOGOTA.CL               0.023264               0.277880  -0.815281
# BVC.CL                  0.124328               0.255527   0.703600
# CELSIA.CL               0.176741               0.273361   2.542877
# CEMARGOS.CL             0.063385               0.392139   2.623429
# CIBEST.CL               0.199216               0.354776   0.233309
# CNEC.CL                -0.151660               0.397962   2.794582
# CONCONCRET.CL          -0.076334               1.086295  15.803517
# CORFICOLCF.CL          -0.008337               0.290148   0.062968
# ECOPETROL.CL            0.155334               0.388492  -0.234071
# ENKA.CL                 0.080472               0.395913   1.925879
# ETB.CL                 -0.217942               0.344598   0.749387
# EXITO.CL                0.050269               0.337661   1.200495
# GEB.CL                  0.148578               0.238899   0.383193
# GRUBOLIVAR.CL           0.081081               0.290012   1.131482
# GRUPOARGOS.CL           0.039999               0.464766   3.779754
# GRUPOAVAL.CL            0.012158               0.279840   0.630716
# GRUPOSURA.CL            0.076247               0.410999   1.047605
# HCOLSEL.CL              0.111639               0.207405  -0.946509
# ICOLCAP.CL              0.105568               0.208947  -0.656157
# ISA.CL                  0.198946               0.304166   0.471124
# MINEROS.CL              0.298425               0.362127   1.513430
# NUTRESA.CL              0.326457               0.482818   4.686878
# PFAVAL.CL               0.020754               0.277128  -1.096382
# PFCIBEST.CL             0.180618               0.304481  -0.135423
# PFCORFICOL.CL           0.017116               0.292412   0.256230
# PFDAVVNDA.CL            0.047440               0.300995   0.455640
# PFGRUPOARG.CL           0.026834               0.368499  -0.715020
# PFGRUPSURA.CL           0.069580               0.388503   0.471816
# PROMIGAS.CL             0.100946               0.293982   1.875609
# TERPEL.CL               0.147432               0.272586   0.634251
# AAPL                    0.288871               0.281328  -0.195536
# AGUAS-A.SN              0.071545               0.275517   0.193751
# AMZN                    0.219934               0.305140  -0.099529
# ANDINA-B.SN             0.130747               0.266846   0.389864
# BAC                     0.154322               0.319981   0.000959
# BAP                     0.142683               0.317511   0.177493
# BRK-B                   0.149299               0.194502  -0.198236
# BSANTANDER.SN           0.146231               0.270392   0.776600
# BVN                     0.214265               0.460221   0.084560
# C                       0.114324               0.344067  -0.046510
# CBU7.L                  0.016984               0.040521   0.216750
# CENCOSUD.SN             0.135060               0.310917  -0.190899
# CFMITNIPSA.SN           0.077273               0.194861  -0.402031
# CHILE.SN                0.167764               0.245865   0.997526
# COLBUN.SN              -0.009060               0.344600  -1.020283
# CONCHATORO.SN           0.029392               0.224961   0.519032
# COPEC.SN                0.015718               0.285954  -0.462637
# CPAC                    0.067725               0.306955   0.115858
# CSPX.L                  0.151193               0.164784  -0.746486
# ECL.SN                  0.040492               0.290982   0.552519
# EIMI.L                  0.085723               0.184907  -0.373135
# ENELCHILE.SN            0.030355               0.318938   0.283591
# ENTEL.SN                0.038842               0.353306   1.203473
# F                       0.053035               0.388778   0.354363
# FALABELLA.SN            0.049458               0.315917   0.253095
# GE                      0.087698               0.362276  -0.084606
# GOOGL                   0.245468               0.279513   0.141243
# IAM.SN                  0.078028               0.274018   0.096316
# IJPA.L                  0.078648               0.172748  -0.503184
# ITAUCL.SN              -0.033963               0.297228  -0.127172
# JETS                    0.015977               0.355036   0.173334
# JNJ                     0.104277               0.177695  -0.214683
# JPM                     0.211998               0.276866   0.076906
# META                    0.212656               0.364444   0.043195
# NKE                     0.012111               0.313430   0.290720
# NVDA                    0.760364               0.471121   0.348908
# PARAUCO.SN              0.137433               0.328608  -0.987176
# PBR                     0.262380               0.521944   0.721840
# PFE                     0.028068               0.242325   0.153957
# RIPLEY.SN               0.092504               0.373443   0.166365
# SCCO                    0.247127               0.364894   0.152857
# SGLD.L                  0.149996               0.145504   0.113471
# SMU.SN                  0.086877               0.279112   0.645638
# SPXS.L                  0.153251               0.165201  -0.734170
# SUAS.L                  0.138203               0.167425  -0.549797
# URA                     0.177344               0.380114   0.388576
# VAPORES.SN              0.160137               0.396436  -0.650763
# VOLCABC1.LM             0.104273               0.595705   1.039365
# VOO                     0.155726               0.174915  -0.600512
#
#                  Kurtosis  Cornish-Fisher VaR (5%)  Historic CVaR (5%)  \
# Ticker
# BOGOTA.CL       13.093865                 0.061626            0.097131
# BVC.CL           7.053813                 0.044306            0.069545
# CELSIA.CL       25.809023                 0.008984            0.069179
# CEMARGOS.CL     40.911549                -0.002237            0.103420
# CIBEST.CL       15.683459                 0.059260            0.097414
# CNEC.CL         32.571353                 0.007466            0.105538
# CONCONCRET.CL  324.746873                -2.078750            0.140517
# CORFICOLCF.CL    8.120655                 0.059528            0.092212
# ECOPETROL.CL     9.402463                 0.079490            0.113031
# ENKA.CL         14.283427                 0.040297            0.099697
# ETB.CL           9.769384                 0.063698            0.113355
# EXITO.CL        13.001525                 0.047446            0.096864
# GEB.CL           7.826129                 0.043584            0.069989
# GRUBOLIVAR.CL   13.315996                 0.040851            0.087224
# GRUPOARGOS.CL   69.827892                -0.068785            0.125785
# GRUPOAVAL.CL     9.910068                 0.049275            0.086756
# GRUPOSURA.CL    16.096960                 0.056510            0.117039
# HCOLSEL.CL      25.637732                 0.038279            0.061746
# ICOLCAP.CL      22.367189                 0.038458            0.060527
# ISA.CL           6.758539                 0.055016            0.087927
# MINEROS.CL      19.524258                 0.035285            0.089918
# NUTRESA.CL      47.112417                -0.072162            0.104683
# PFAVAL.CL       16.193770                 0.061772            0.093144
# PFCIBEST.CL     10.287811                 0.059695            0.085961
# PFCORFICOL.CL    8.993488                 0.056587            0.090865
# PFDAVVNDA.CL    10.267895                 0.054209            0.088286
# PFGRUPOARG.CL   23.671643                 0.069454            0.112660
# PFGRUPSURA.CL   18.908021                 0.060022            0.110795
# PROMIGAS.CL     27.094924                 0.019823            0.085549
# TERPEL.CL        8.226034                 0.046906            0.079244
# AAPL             5.083081                 0.058017            0.082014
# AGUAS-A.SN       7.871642                 0.053911            0.079781
# AMZN             4.439446                 0.063710            0.089718
# ANDINA-B.SN      5.967045                 0.050496            0.073040
# BAC              6.155126                 0.065228            0.095854
# BAP              8.157371                 0.060963            0.090910
# BRK-B            5.540954                 0.040720            0.057133
# BSANTANDER.SN    6.919187                 0.045878            0.071033
# BVN              9.144205                 0.088150            0.126078
# C                7.984146                 0.069812            0.105081
# CBU7.L           6.046442                 0.008059            0.012274
# CENCOSUD.SN      9.182969                 0.063329            0.089756
# CFMITNIPSA.SN   10.596702                 0.040767            0.059339
# CHILE.SN         9.342452                 0.037215            0.064921
# COLBUN.SN       22.832374                 0.070045            0.093421
# CONCHATORO.SN    5.462059                 0.043161            0.059653
# COPEC.SN         7.927898                 0.064039            0.083717
# CPAC             5.813312                 0.062864            0.095453
# CSPX.L           9.963549                 0.035392            0.051682
# ECL.SN           6.246509                 0.054582            0.083069
# EIMI.L           5.407606                 0.040927            0.056774
# ENELCHILE.SN     6.166207                 0.063561            0.096803
# ENTEL.SN        13.177851                 0.049622            0.099799
# F                7.348915                 0.074576            0.114205
# FALABELLA.SN    10.089584                 0.059600            0.091580
# GE               5.066385                 0.077434            0.113837
# GOOGL            3.797004                 0.055620            0.074626
# IAM.SN           8.296710                 0.054233            0.081300
# IJPA.L           7.543333                 0.038081            0.054119
# ITAUCL.SN       15.991911                 0.057183            0.091568
# JETS            13.504811                 0.065349            0.106259
# JNJ              4.800368                 0.038219            0.051708
# JPM              8.053204                 0.053027            0.082264
# META             6.787528                 0.072366            0.105660
# NKE              7.618744                 0.061459            0.089511
# NVDA             4.456203                 0.084522            0.117417
# PARAUCO.SN      14.780450                 0.071221            0.099931
# PBR             11.663530                 0.082337            0.140307
# PFE              4.900353                 0.050463            0.070859
# RIPLEY.SN        8.105217                 0.072991            0.107610
# SCCO             4.186924                 0.072984            0.100213
# SGLD.L           5.008106                 0.028336            0.039937
# SMU.SN           5.376240                 0.051132            0.077660
# SPXS.L           9.981746                 0.035375            0.051896
# SUAS.L          10.008602                 0.035023            0.051167
# URA              4.271811                 0.073547            0.100399
# VAPORES.SN      10.208139                 0.086177            0.121389
# VOLCABC1.LM     11.279894                 0.089171            0.161704
# VOO              8.943660                 0.037230            0.055724
#
#                Sharpe Ratio  Max Drawdown
# Ticker
# BOGOTA.CL          0.083721     -0.633000
# BVC.CL             0.486555     -0.356135
# CELSIA.CL          0.646548     -0.476794
# CEMARGOS.CL        0.161639     -0.782276
# CIBEST.CL          0.561526     -0.581656
# CNEC.CL           -0.381092     -0.923684
# CONCONCRET.CL     -0.070270     -0.864859
# CORFICOLCF.CL     -0.028732     -0.600359
# ECOPETROL.CL       0.399838     -0.598050
# ENKA.CL            0.203258     -0.562287
# ETB.CL            -0.632452     -0.928790
# EXITO.CL           0.148873     -0.659980
# GEB.CL             0.621928     -0.460182
# GRUBOLIVAR.CL      0.279578     -0.534127
# GRUPOARGOS.CL      0.086062     -0.645726
# GRUPOAVAL.CL       0.043446     -0.631598
# GRUPOSURA.CL       0.185516     -0.601465
# HCOLSEL.CL         0.538266     -0.457327
# ICOLCAP.CL         0.505239     -0.440915
# ISA.CL             0.654071     -0.437315
# MINEROS.CL         0.824089     -0.623687
# NUTRESA.CL         0.676149     -0.382365
# PFAVAL.CL          0.074891     -0.638174
# PFCIBEST.CL        0.593198     -0.536017
# PFCORFICOL.CL      0.058535     -0.584283
# PFDAVVNDA.CL       0.157611     -0.620423
# PFGRUPOARG.CL      0.072819     -0.698413
# PFGRUPSURA.CL      0.179097     -0.720719
# PROMIGAS.CL        0.343375     -0.444339
# TERPEL.CL          0.540865     -0.480604
# AAPL               1.026811     -0.346408
# AGUAS-A.SN         0.259677     -0.624142
# AMZN               0.720766     -0.548307
# ANDINA-B.SN        0.489970     -0.446745
# BAC                0.482285     -0.464260
# BAP                0.449379     -0.577136
# BRK-B              0.767599     -0.264770
# BSANTANDER.SN      0.540810     -0.477094
# BVN                0.465570     -0.689323
# C                  0.332273     -0.534781
# CBU7.L             0.419155     -0.140871
# CENCOSUD.SN        0.434395     -0.681302
# CFMITNIPSA.SN      0.396557     -0.472281
# CHILE.SN           0.682340     -0.396780
# COLBUN.SN         -0.026292     -0.710529
# CONCHATORO.SN      0.130652     -0.329547
# COPEC.SN           0.054968     -0.592895
# CPAC               0.220635     -0.537636
# CSPX.L             0.917527     -0.295079
# ECL.SN             0.139156     -0.759098
# EIMI.L             0.463598     -0.367735
# ENELCHILE.SN       0.095174     -0.691931
# ENTEL.SN           0.109938     -0.631739
# F                  0.136415     -0.627441
# FALABELLA.SN       0.156553     -0.748010
# GE                 0.242075     -0.811628
# GOOGL              0.878198     -0.418639
# IAM.SN             0.284756     -0.615676
# IJPA.L             0.455276     -0.318206
# ITAUCL.SN         -0.114266     -0.772950
# JETS               0.045000     -0.647329
# JNJ                0.586831     -0.205645
# JPM                0.765705     -0.396032
# META               0.583508     -0.760252
# NKE                0.038639     -0.678727
# NVDA               1.613947     -0.659360
# PARAUCO.SN         0.418227     -0.684833
# PBR                0.502697     -0.710030
# PFE                0.115828     -0.571144
# RIPLEY.SN          0.247705     -0.803504
# SCCO               0.677258     -0.502005
# SGLD.L             1.030874     -0.194443
# SMU.SN             0.311263     -0.608558
# SPXS.L             0.927660     -0.294863
# SUAS.L             0.825466     -0.293075
# URA                0.466554     -0.571983
# VAPORES.SN         0.403942     -0.609036
# VOLCABC1.LM        0.175042     -0.891906
# VOO                0.890295     -0.317618

# %% [markdown]
# ### **Technical Indicators for selected stock**

# %%
# Determine a number of periods for the calculation of the moving averages
# MA_terms = 5*4 # Uncomment for daily
MA_terms = 10 # Uncomment for weekly

# %%
stock = 'PFGRUPSURA.CL' #'BCOLOMBIA.CL'  #'NVDA'
rk.technical_indicators(stocks[stock], time_window=MA_terms, return_df=True, indicators=['SMA', 'EMA', 'MACD'], macd_params=[8, 17, 9])
# rk.technical_indicators(stocks[stock], time_window=MA_terms, return_df=True, indicators=['SMA', 'EMA', 'MACD'], macd_params=[12, 26, 9])
# Out:
#                        PFGRUPSURA.CL         SMA10         EMA10  \
# Date
# 2015-12-07/2015-12-13   22964.582031           NaN  22964.582031
# 2015-12-14/2015-12-20   22964.582031           NaN  22964.582031
# 2015-12-21/2015-12-27   22786.238281           NaN  22932.155895
# 2015-12-28/2016-01-03   23946.544922           NaN  23116.590263
# 2016-01-04/2016-01-10   22831.791016           NaN  23064.808582
# ...                              ...           ...           ...
# 2025-11-10/2025-11-16   47680.000000  38915.226172  40550.399685
# 2025-11-17/2025-11-23   44980.000000  39865.106250  41355.781561
# 2025-11-24/2025-11-30   45080.000000  40662.718750  42032.912186
# 2025-12-01/2025-12-07   44000.000000  41538.345313  42390.564516
# 2025-12-08/2025-12-14            NaN           NaN  42390.564516
#
#                        SMA10 Signal  EMA10 Signal  MACD Signal
# Date
# 2015-12-07/2015-12-13         False         False        False
# 2015-12-14/2015-12-20         False         False        False
# 2015-12-21/2015-12-27         False         False        False
# 2015-12-28/2016-01-03         False          True         True
# 2016-01-04/2016-01-10         False         False         True
# ...                             ...           ...          ...
# 2025-11-10/2025-11-16          True          True         True
# 2025-11-17/2025-11-23          True          True         True
# 2025-11-24/2025-11-30          True          True         True
# 2025-12-01/2025-12-07          True          True         True
# 2025-12-08/2025-12-14         False         False         True
#
# [523 rows x 6 columns]

# %% [markdown]
# ### **Signals across all stocks**

# %%
signals = []
for stock in stocks.columns:
    stock_signals = rk.technical_indicators(stocks[stock], indicators=['SMA', 'EMA', 'MACD'], time_window=MA_terms, macd_params=[12, 26, 9], return_df=True, plot=False, signal_tolerance=.975).iloc[-1]
    stock_signals = pd.DataFrame(stock_signals).T
    stock_signals.index = [stock]
    stock_signals.rename(columns={stock: 'Price'}, inplace=True)
    signals.append(stock_signals)

signals = pd.concat(signals, axis=0)

# %%
signals
# Out:
#                      Price        SMA10          EMA10 SMA10 Signal  \
# BOGOTA.CL              NaN          NaN   37112.430933        False
# BVC.CL                 NaN          NaN   13242.613706        False
# CELSIA.CL              NaN          NaN    4852.326327        False
# CEMARGOS.CL            NaN          NaN   10486.540732        False
# CIBEST.CL              NaN          NaN   63802.541208        False
# CNEC.CL             6240.0       5838.0    5943.435732         True
# CONCONCRET.CL          NaN          NaN     452.494236        False
# CORFICOLCF.CL          NaN          NaN   18042.295768        False
# ECOPETROL.CL           NaN          NaN    1850.170822        False
# ENKA.CL                NaN          NaN      20.174273        False
# ETB.CL                 NaN          NaN      48.956297        False
# EXITO.CL               NaN          NaN    4073.490463        False
# GEB.CL                 NaN          NaN    3104.858945        False
# GRUBOLIVAR.CL          NaN          NaN   85536.217845        False
# GRUPOARGOS.CL          NaN          NaN   17647.397201        False
# GRUPOAVAL.CL           NaN          NaN      735.55663        False
# GRUPOSURA.CL           NaN          NaN   51064.858195        False
# HCOLSEL.CL             NaN          NaN   22271.597467        False
# ICOLCAP.CL             NaN          NaN   19827.202841        False
# ISA.CL                 NaN          NaN   24296.280013        False
# MINEROS.CL             NaN          NaN   13951.581684        False
# NUTRESA.CL             NaN          NaN  239294.757111        False
# PFAVAL.CL              NaN          NaN      749.55115        False
# PFCIBEST.CL            NaN          NaN    56687.59399        False
# PFCORFICOL.CL          NaN          NaN   17052.697566        False
# PFDAVVNDA.CL           NaN          NaN   27044.550569        False
# PFGRUPOARG.CL          NaN          NaN   12611.224314        False
# PFGRUPSURA.CL          NaN          NaN   42390.564516        False
# PROMIGAS.CL            NaN          NaN    6394.093911        False
# TERPEL.CL              NaN          NaN   16483.426241        False
# AAPL            277.890015   267.711795     267.989816         True
# AGUAS-A.SN             NaN          NaN     355.626779        False
# AMZN            226.889999      228.727     228.907103         True
# ANDINA-B.SN            NaN          NaN    4102.734186        False
# BAC              53.900002    52.238541      52.372803         True
# BAP             269.339996   258.686996      260.34737         True
# BRK-B           497.230011   497.861005     499.790338         True
# BSANTANDER.SN          NaN          NaN      67.406147        False
# BVN              24.879999       23.926      23.678547         True
# C               108.919998   100.928506     102.377869         True
# CBU7.L          142.470001      142.745     142.557024         True
# CENCOSUD.SN            NaN          NaN    2867.949523        False
# CFMITNIPSA.SN  4868.399902  4595.055957    4645.819084         True
# CHILE.SN               NaN          NaN     164.569119        False
# COLBUN.SN              NaN          NaN     144.841316        False
# CONCHATORO.SN          NaN          NaN    1053.212912        False
# COPEC.SN               NaN          NaN     6742.22914        False
# CPAC                  6.78        7.049       6.907357        False
# CSPX.L           733.23999   720.541992     720.751137         True
# ECL.SN                 NaN          NaN    1347.640483        False
# EIMI.L               44.18     44.01357       43.79955         True
# ENELCHILE.SN           NaN          NaN      71.808145        False
# ENTEL.SN               NaN          NaN    4309.565701        False
# F                    13.14    12.825389       12.81227         True
# FALABELLA.SN           NaN          NaN    5895.322156        False
# GE              287.190002   297.356003      292.61708        False
# GOOGL           313.514923   283.919283     288.308921         True
# IAM.SN                 NaN          NaN     942.303412        False
# IJPA.L           68.489998     67.70808      67.701094         True
# ITAUCL.SN              NaN          NaN   16909.412978        False
# JETS                 27.43       25.503      25.914792         True
# JNJ             201.619995    195.02596     195.034693         True
# JPM             315.209991   306.772418     308.272702         True
# META            666.799988   662.251996     665.489022         True
# NKE              63.540001     64.46699      65.157482         True
# NVDA            185.550003   185.719693      183.35648         True
# PARAUCO.SN             NaN          NaN    2742.468465        False
# PBR                  12.24       12.233      12.357639         True
# PFE                  25.77    24.863938       25.12314         True
# RIPLEY.SN              NaN          NaN     449.134061        False
# SCCO            141.039993    131.99384     130.645359         True
# SGLD.L          403.929993   396.392856     391.866531         True
# SMU.SN                 NaN          NaN     149.838169        False
# SPXS.L          1364.72998  1342.211938    1341.988555         True
# SUAS.L           17.790001     17.55911       17.55446         True
# URA              47.810001       48.697      47.005599         True
# VAPORES.SN             NaN          NaN      48.213548        False
# VOLCABC1.LM           0.54       0.5092        0.49642         True
# VOO             628.609985   618.900995     618.744531         True
#
#               EMA10 Signal MACD Signal
# BOGOTA.CL            False        True
# BVC.CL               False        True
# CELSIA.CL            False       False
# CEMARGOS.CL          False        True
# CIBEST.CL            False        True
# CNEC.CL               True        True
# CONCONCRET.CL        False        True
# CORFICOLCF.CL        False        True
# ECOPETROL.CL         False        True
# ENKA.CL              False       False
# ETB.CL               False        True
# EXITO.CL             False        True
# GEB.CL               False        True
# GRUBOLIVAR.CL        False        True
# GRUPOARGOS.CL        False        True
# GRUPOAVAL.CL         False        True
# GRUPOSURA.CL         False        True
# HCOLSEL.CL           False        True
# ICOLCAP.CL           False        True
# ISA.CL               False        True
# MINEROS.CL           False        True
# NUTRESA.CL           False        True
# PFAVAL.CL            False        True
# PFCIBEST.CL          False        True
# PFCORFICOL.CL        False        True
# PFDAVVNDA.CL         False        True
# PFGRUPOARG.CL        False        True
# PFGRUPSURA.CL        False        True
# PROMIGAS.CL          False       False
# TERPEL.CL            False        True
# AAPL                  True        True
# AGUAS-A.SN           False        True
# AMZN                  True       False
# ANDINA-B.SN          False        True
# BAC                   True        True
# BAP                   True       False
# BRK-B                 True        True
# BSANTANDER.SN        False        True
# BVN                   True        True
# C                     True        True
# CBU7.L                True       False
# CENCOSUD.SN          False       False
# CFMITNIPSA.SN         True        True
# CHILE.SN             False        True
# COLBUN.SN            False       False
# CONCHATORO.SN        False       False
# COPEC.SN             False       False
# CPAC                  True       False
# CSPX.L                True        True
# ECL.SN               False       False
# EIMI.L                True       False
# ENELCHILE.SN         False       False
# ENTEL.SN             False        True
# F                     True        True
# FALABELLA.SN         False        True
# GE                    True       False
# GOOGL                 True        True
# IAM.SN               False        True
# IJPA.L                True       False
# ITAUCL.SN            False        True
# JETS                  True        True
# JNJ                   True        True
# JPM                   True       False
# META                  True       False
# NKE                   True       False
# NVDA                  True       False
# PARAUCO.SN           False        True
# PBR                   True        True
# PFE                   True        True
# RIPLEY.SN            False       False
# SCCO                  True        True
# SGLD.L                True        True
# SMU.SN               False       False
# SPXS.L                True       False
# SUAS.L                True       False
# URA                   True       False
# VAPORES.SN           False       False
# VOLCABC1.LM           True        True
# VOO                   True       False

# %% [markdown]
# ### **Stock filtering by signal**

# %%
signals_filtered = signals[np.int64(signals['MACD Signal']) + np.int64(signals[f'SMA{MA_terms} Signal']) + np.int64(signals[f'EMA{MA_terms} Signal']) >= 2]

# %%
selected_stocks_rets = rets[signals_filtered.index]
selected_stocks_stocks = stocks[signals_filtered.index]

# %%
selected_stocks_rets.index = selected_stocks_rets.index.astype('str').str.split('/').str[1]
selected_stocks_stocks.index = selected_stocks_stocks.index.astype('str').str.split('/').str[1]

rets.index = rets.index.astype('str').str.split('/').str[1]
stocks.index = stocks.index.astype('str').str.split('/').str[1]

# %% [markdown]
# ### **Export datasets and an index for the Sharpe-Ratio maximizing allocation**

# %%
# Selected stocks dataset
selected_stocks_rets.to_csv('selected_stocks_rets.csv')
selected_stocks_stocks.to_csv('selected_stocks_stocks.csv')

# Concatenated returns and stock prices datasets
rets.to_csv('all_rets.csv')
stocks.to_csv('all_stocks.csv')
