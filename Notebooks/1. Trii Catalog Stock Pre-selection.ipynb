# %% [markdown]
# ### **Load libraries**

# %%
import sys
sys.path.append('../src')
import pandas as pd
import numpy as np
import ipywidgets as widgets
from IPython.display import display
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import risk_kit as rk
import importlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# ### **Define ticker names**

# %%
col_stock_list_path = 'colombia_stocks_trii.csv'
global_stock_list_path = 'global_stocks_trii.csv'

ticker_list_col = list(pd.read_csv(col_stock_list_path, header=None)[0])
ticker_list_glob = list(pd.read_csv(global_stock_list_path, header=None)[0])

# %%
""" Alt method
col_stock_list_path = 'colombia_stocks_trii.csv'
global_stock_list_path = 'global_stocks_trii.csv'

with open(col_stock_list_path) as s:
    ticker_list_col = []
    [ticker_list_col.append(l.replace('\n', '')) for l in s]
    s.close()
with open(global_stock_list_path) as s:
    ticker_list_global = []
    [ticker_list_global.append(l.replace('\n', '')) for l in s]
    s.close()
"""
# Out:
# " Alt method\ncol_stock_list_path = 'colombia_stocks_trii.csv'\nglobal_stock_list_path = 'global_stocks_trii.csv'\n\nwith open(col_stock_list_path) as s:\n    ticker_list_col = []\n    [ticker_list_col.append(l.replace('\n', '')) for l in s]\n    s.close()\nwith open(global_stock_list_path) as s:\n    ticker_list_global = []\n    [ticker_list_global.append(l.replace('\n', '')) for l in s]\n    s.close()\n"

# %%
ticker_list_glob['SGLD.L']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 del ticker_list_glob['SGLD.L']
#
# TypeError: list indices must be integers or slices, not str

# %%
# Define the number of periods per year for all calculations
# 252 is an approximation for daily
# 54 for weekly
# 12 for monthly
periods_per_year = 54

# %% [markdown]
# ### **Extract data from YFinance**

# %%
days_of_data = 365*10
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=days_of_data)

# %%
#interval = '1d'   # Uncomment for daily data
interval = '1wk'  # Uncomment for weekly data
# interval = '1mo' # Uncomment for monthly data

col_stocks_raw = yf.download(ticker_list_col, interval=interval, start=start_date, end=end_date, auto_adjust=True)['Close']
global_stocks_raw = yf.download(ticker_list_glob, interval=interval, start=start_date, end=end_date, auto_adjust=True)['Close']
# Out:
# [*********************100%***********************]  37 of 37 completed
#
# 1 Failed download:
# ['LTMCO.CL']: YFPricesMissingError('possibly delisted; no price data found  (1wk 2015-09-04 -> 2025-09-01)')
# [**********************94%********************   ]  46 of 49 completedHTTP Error 404:
# HTTP Error 404:
# [*********************100%***********************]  49 of 49 completed
#
# 7 Failed downloads:
# ['ICHNA.XD', 'SQMBCO.CL', 'IWVLM.XD', 'ENELAMCO.CL']: YFPricesMissingError('possibly delisted; no price data found  (1wk 2015-09-04 -> 2025-09-01)')
# ['IBO1', 'CFMITNIPCO', 'LTMCO']: YFTzMissingError('possibly delisted; no timezone found')

# %% [markdown]
# ### **Preprocessing**

# %%
# Assign a frequency to the index of the dataframes
# col_stocks_raw.index = col_stocks_raw.index.to_period(freq='D') # Uncomment to set frequency as Daily
# global_stocks_raw.index = global_stocks_raw.index.to_period(freq='D') # Uncomment to set ferquency as Daily

col_stocks_raw.index = col_stocks_raw.index.to_period(freq='W') # Uncomment to set frequency as Weekly
global_stocks_raw.index = global_stocks_raw.index.to_period(freq='W') # Uncomment to set ferquency as Weekly

# col_stocks_raw.index = col_stocks_raw.index.to_period(freq='M') # Uncomment to set frequency as Monthly
# global_stocks_raw.index = global_stocks_raw.index.to_period(freq='M') # Uncomment to set frequency as Monthly

# %%
# Merge Col and Global stock prices and returns data
stocks = pd.concat([col_stocks_raw, global_stocks_raw], axis='columns').sort_index()

# %%
stocks_not_missing = stocks.columns[stocks.isna().sum() < stocks.shape[0]*.15]

# %%
# For days without stock price info, assume the stock price is the same of the previous day
stocks = stocks[stocks_not_missing].fillna(method='bfill')

# Convert from stock prices into returns
rets = stocks.pct_change().iloc[1:]
# Out:
# C:\Users\jumar\AppData\Local\Temp\ipykernel_48112\3483962844.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   stocks = stocks[stocks_not_missing].fillna(method='bfill')

# %%
# Define start and end dates of the analysis
days_of_analysis = 365*10   # 5 years
end_date = str(datetime.date.today())
start_date = str(datetime.date.today() - datetime.timedelta(days=days_of_analysis))

# %%
rets = rets.loc[start_date:end_date]
stocks = stocks.loc[start_date:end_date]

# %%
(rets.shape, stocks.shape)
# Out:
# ((521, 54), (522, 54))

# %% [markdown]
# ### **Initial examination**

# %%
df1_to_plot = rets
df2_to_plot = stocks

fig, axes = plt.subplots(2, 1, figsize=(12, 10))
df1_to_plot.plot(ax = axes[0], legend=False)
df2_to_plot.plot(ax=axes[1], legend=False)
plt.tight_layout()

# %%
summary_stats = rk.summary_stats(rets, riskfree_rate=0, periods_per_year=periods_per_year)
summary_stats
# Out:
#                Annualized Return  Annualized Volatility   Skewness  \
# Ticker
# BOGOTA.CL               0.013002               0.276753  -0.813516
# BVC.CL                  0.116595               0.253035   0.681931
# CELSIA.CL               0.125668               0.282956   2.286295
# CEMARGOS.CL             0.042420               0.389737   2.666852
# CIBEST.CL               0.163538               0.358830   0.266150
# CNEC.CL                -0.131962               0.399117   2.759476
# CONCONCRET.CL          -0.092025               1.087372  15.792768
# CORFICOLCF.CL          -0.006758               0.290366   0.059902
# ECOPETROL.CL            0.100419               0.388548  -0.262544
# ENKA.CL                 0.071172               0.395772   1.943080
# ETB.CL                 -0.219895               0.349615   0.654039
# EXITO.CL               -0.008563               0.348584   1.099388
# GEB.CL                  0.131959               0.238484   0.399422
# GRUBOLIVAR.CL           0.059062               0.287702   1.183502
# GRUPOARGOS.CL           0.030306               0.467638   3.720820
# GRUPOAVAL.CL           -0.004035               0.282215   0.680709
# GRUPOSURA.CL            0.058539               0.411030   1.040289
# HCOLSEL.CL              0.094055               0.211113  -0.830750
# ICOLCAP.CL              0.082482               0.211076  -0.604956
# ISA.CL                  0.176222               0.303410   0.480295
# MINEROS.CL              0.241052               0.361214   1.546655
# NUTRESA.CL              0.269193               0.462648   5.151494
# PFAVAL.CL              -0.001381               0.277881  -1.051054
# PFCIBEST.CL             0.138761               0.310708  -0.072494
# PFCORFICOL.CL           0.020098               0.293104   0.256589
# PFDAVVNDA.CL            0.026579               0.301143   0.449225
# PFGRUPOARG.CL          -0.003290               0.369527  -0.693308
# PFGRUPSURA.CL           0.046279               0.387899   0.469375
# PROMIGAS.CL             0.080687               0.295326   1.891982
# TERPEL.CL               0.087368               0.280660   0.559167
# AAPL                    0.262169               0.284171  -0.176472
# AMZN                    0.258310               0.304769  -0.137042
# BAC                     0.155048               0.321244  -0.003073
# BRK-B                   0.150876               0.195151  -0.212682
# C                       0.101556               0.344351  -0.041592
# CBU7.L                  0.015925               0.040749   0.216957
# CENCOSUD.SN             0.119907               0.311597  -0.218948
# CHILE.SN                0.136307               0.243453   1.035851
# CSPX.L                  0.150914               0.165376  -0.723935
# EIMI.L                  0.079131               0.188278  -0.310186
# F                       0.042936               0.385733   0.334490
# FALABELLA.SN            0.039762               0.316224   0.257972
# GE                      0.110369               0.362699  -0.090396
# GOOGL                   0.219996               0.274730   0.093100
# JETS                    0.018036               0.355313   0.165882
# JNJ                     0.101589               0.176854  -0.243544
# JPM                     0.212908               0.277673   0.069802
# META                    0.247044               0.361604   0.044390
# NKE                     0.049390               0.313504   0.295709
# NVDA                    0.823770               0.471896   0.328960
# PBR                     0.236912               0.533441   0.727804
# PFE                     0.024949               0.236351   0.032731
# SGLD.L                  0.121223               0.143984   0.094824
# VOO                     0.154623               0.175971  -0.600362
#
#                  Kurtosis  Cornish-Fisher VaR (5%)  Historic CVaR (5%)  \
# Ticker
# BOGOTA.CL       13.288803                 0.061399            0.096779
# BVC.CL           7.179835                 0.044130            0.069545
# CELSIA.CL       23.147095                 0.015975            0.075304
# CEMARGOS.CL     41.979421                -0.003879            0.102846
# CIBEST.CL       15.104411                 0.060624            0.097583
# CNEC.CL         31.697829                 0.008750            0.102332
# CONCONCRET.CL  324.213905                -2.077513            0.140517
# CORFICOLCF.CL    8.108513                 0.059587            0.092212
# ECOPETROL.CL     9.198930                 0.081035            0.114029
# ENKA.CL         14.348640                 0.040042            0.099571
# ETB.CL           9.505759                 0.066248            0.116314
# EXITO.CL        12.055399                 0.052517            0.103810
# GEB.CL           7.904444                 0.043567            0.069989
# GRUBOLIVAR.CL   13.790061                 0.039860            0.087203
# GRUPOARGOS.CL   68.305969                -0.065496            0.125898
# GRUPOAVAL.CL     9.810043                 0.049473            0.086756
# GRUPOSURA.CL    16.102527                 0.056947            0.117039
# HCOLSEL.CL      24.234339                 0.039267            0.062802
# ICOLCAP.CL      21.552217                 0.039345            0.061180
# ISA.CL           6.819391                 0.055063            0.087649
# MINEROS.CL      19.850754                 0.035145            0.090898
# NUTRESA.CL      55.248671                -0.092519            0.099861
# PFAVAL.CL       16.072928                 0.062020            0.093345
# PFCIBEST.CL      9.723657                 0.061368            0.087584
# PFCORFICOL.CL    8.932401                 0.056711            0.090865
# PFDAVVNDA.CL    10.311859                 0.054651            0.089174
# PFGRUPOARG.CL   23.432810                 0.070158            0.112896
# PFGRUPSURA.CL   19.034783                 0.060241            0.111471
# PROMIGAS.CL     26.776632                 0.020288            0.085847
# TERPEL.CL        8.054740                 0.050357            0.084848
# AAPL             4.952329                 0.058930            0.082890
# AMZN             4.442581                 0.063486            0.089718
# BAC              6.084953                 0.065593            0.095854
# BRK-B            5.494381                 0.040969            0.057431
# C                7.979246                 0.070024            0.105412
# CBU7.L           5.959881                 0.008135            0.012287
# CENCOSUD.SN      9.125648                 0.064097            0.091053
# CHILE.SN         9.716179                 0.036674            0.064921
# CSPX.L           9.874252                 0.035442            0.051682
# EIMI.L           5.263040                 0.041445            0.057236
# F                7.424292                 0.074403            0.113296
# FALABELLA.SN    10.063861                 0.059790            0.091600
# GE               5.074265                 0.077214            0.113837
# GOOGL            3.877763                 0.055452            0.074626
# JETS            13.482221                 0.065489            0.106259
# JNJ              4.840973                 0.038248            0.051708
# JPM              7.995340                 0.053297            0.082295
# META             6.912188                 0.071123            0.103739
# NKE              7.623396                 0.060737            0.088577
# NVDA             4.424815                 0.084434            0.117417
# PBR             10.935290                 0.085504            0.141754
# PFE              4.354639                 0.050751            0.069443
# SGLD.L           5.100998                 0.028554            0.040355
# VOO              8.774505                 0.037567            0.055974
#
#                Sharpe Ratio  Max Drawdown
# Ticker
# BOGOTA.CL          0.046982     -0.633000
# BVC.CL             0.460786     -0.356135
# CELSIA.CL          0.444127     -0.492160
# CEMARGOS.CL        0.108844     -0.782714
# CIBEST.CL          0.455753     -0.581655
# CNEC.CL           -0.330635     -0.923684
# CONCONCRET.CL     -0.084630     -0.864859
# CORFICOLCF.CL     -0.023273     -0.600359
# ECOPETROL.CL       0.258446     -0.615934
# ENKA.CL            0.179830     -0.562287
# ETB.CL            -0.628962     -0.928790
# EXITO.CL          -0.024566     -0.659980
# GEB.CL             0.553325     -0.478890
# GRUBOLIVAR.CL      0.205289     -0.534128
# GRUPOARGOS.CL      0.064806     -0.645726
# GRUPOAVAL.CL      -0.014297     -0.631598
# GRUPOSURA.CL       0.142421     -0.601465
# HCOLSEL.CL         0.445518     -0.457327
# ICOLCAP.CL         0.390770     -0.440915
# ISA.CL             0.580804     -0.451207
# MINEROS.CL         0.667340     -0.623688
# NUTRESA.CL         0.581852     -0.384842
# PFAVAL.CL         -0.004969     -0.638174
# PFCIBEST.CL        0.446594     -0.536017
# PFCORFICOL.CL      0.068571     -0.584283
# PFDAVVNDA.CL       0.088259     -0.620423
# PFGRUPOARG.CL     -0.008905     -0.698413
# PFGRUPSURA.CL      0.119308     -0.721625
# PROMIGAS.CL        0.273215     -0.482563
# TERPEL.CL          0.311294     -0.480604
# AAPL               0.922576     -0.346407
# AMZN               0.847559     -0.548307
# BAC                0.482648     -0.464260
# BRK-B              0.773123     -0.264770
# C                  0.294919     -0.534781
# CBU7.L             0.390807     -0.140871
# CENCOSUD.SN        0.384815     -0.690865
# CHILE.SN           0.559888     -0.396780
# CSPX.L             0.912553     -0.295079
# EIMI.L             0.420290     -0.367735
# F                  0.111309     -0.641058
# FALABELLA.SN       0.125741     -0.749691
# GE                 0.304300     -0.811628
# GOOGL              0.800772     -0.418639
# JETS               0.050760     -0.647329
# JNJ                0.574424     -0.205645
# JPM                0.766756     -0.396032
# META               0.683189     -0.760252
# NKE                0.157542     -0.678727
# NVDA               1.745660     -0.659360
# PBR                0.444121     -0.710030
# PFE                0.105560     -0.571144
# SGLD.L             0.841924     -0.194443
# VOO                0.878686     -0.317618

# %% [markdown]
# ### **Technical Indicators for selected stock**

# %%
# Determine a number of periods for the calculation of the moving averages
# MA_terms = 5*4 # Uncomment for daily
MA_terms = 10 # Uncomment for weekly

# %%
stock = 'PFGRUPSURA.CL' #'BCOLOMBIA.CL'  #'NVDA'
rk.technical_indicators(stocks[stock], time_window=MA_terms, return_df=True, indicators=['SMA', 'EMA', 'MACD'], macd_params=[8, 17, 9])
# rk.technical_indicators(stocks[stock], time_window=MA_terms, return_df=True, indicators=['SMA', 'EMA', 'MACD'], macd_params=[12, 26, 9])
# Out:
#                        PFGRUPSURA.CL         SMA10         EMA10  \
# Date
# 2015-08-31/2015-09-06   23034.248047           NaN  23034.248047
# 2015-09-07/2015-09-13   23991.115234           NaN  23208.223899
# 2015-09-14/2015-09-20   24434.884766           NaN  23431.253148
# 2015-09-21/2015-09-27   24046.587891           NaN  23543.132192
# 2015-09-28/2015-10-04   24328.566406           NaN  23685.938413
# ...                              ...           ...           ...
# 2025-07-28/2025-08-03   37120.000000  38003.983594  37883.570422
# 2025-08-04/2025-08-10   36980.000000  38007.484766  37719.284891
# 2025-08-11/2025-08-17   36480.000000  37929.290625  37493.960365
# 2025-08-18/2025-08-24   36100.000000  37769.515234  37240.513026
# 2025-08-25/2025-08-31   35640.000000  37559.778125  36949.510658
#
#                        SMA10 Signal  EMA10 Signal  MACD Signal
# Date
# 2015-08-31/2015-09-06         False         False        False
# 2015-09-07/2015-09-13         False          True         True
# 2015-09-14/2015-09-20         False          True         True
# 2015-09-21/2015-09-27         False          True         True
# 2015-09-28/2015-10-04         False          True         True
# ...                             ...           ...          ...
# 2025-07-28/2025-08-03         False         False        False
# 2025-08-04/2025-08-10         False         False        False
# 2025-08-11/2025-08-17         False         False        False
# 2025-08-18/2025-08-24         False         False        False
# 2025-08-25/2025-08-31         False         False        False
#
# [522 rows x 6 columns]

# %% [markdown]
# ### **Signals across all stocks**

# %%
signals = []
for stock in stocks.columns:
    stock_signals = rk.technical_indicators(stocks[stock], indicators=['SMA', 'EMA', 'MACD'], time_window=MA_terms, macd_params=[12, 26, 9], return_df=True, plot=False, signal_tolerance=.975).iloc[-1]
    stock_signals = pd.DataFrame(stock_signals).T
    stock_signals.index = [stock]
    stock_signals.rename(columns={stock: 'Price'}, inplace=True)
    signals.append(stock_signals)

signals = pd.concat(signals, axis=0)

# %%
signals
# Out:
#                      Price         SMA10          EMA10 SMA10 Signal  \
# BOGOTA.CL          34973.5  32739.915234   33174.263084         True
# BVC.CL             12600.0       12194.0   12281.187852         True
# CELSIA.CL           4790.0   4709.976514    4698.984308         True
# CEMARGOS.CL         9970.0  10337.370996   10335.844204        False
# CIBEST.CL          59000.0       54806.0   55493.888288         True
# CNEC.CL             7900.0        6605.0    6698.713964         True
# CONCONCRET.CL        441.0         467.0      461.72798        False
# CORFICOLCF.CL      18280.0       17796.0   17839.866994         True
# ECOPETROL.CL        1890.0        1801.5    1817.531735         True
# ENKA.CL               19.5         18.87      18.967211         True
# ETB.CL                50.0         52.45      51.881118        False
# EXITO.CL            3330.0        3090.0    3069.478025         True
# GEB.CL              2950.0   2938.695923    2930.905997         True
# GRUBOLIVAR.CL      76140.0  72301.570312   73021.962083         True
# GRUPOARGOS.CL      17280.0  19445.925684   18663.268002        False
# GRUPOAVAL.CL    642.663757    596.960492     607.117298         True
# GRUPOSURA.CL       46360.0  48428.382031   47080.016917        False
# HCOLSEL.CL         20593.0  19496.100781   19661.712067         True
# ICOLCAP.CL         18330.0      17484.05   17603.037946         True
# ISA.CL             21800.0       21082.0   21396.375605         True
# MINEROS.CL         10200.0   7900.985205    8150.825348         True
# NUTRESA.CL        149480.0      134116.0  136369.407937         True
# PFAVAL.CL       662.646912    599.223578     611.628766         True
# PFCIBEST.CL        50300.0       47108.0   47474.487967         True
# PFCORFICOL.CL      16820.0       16260.0   16403.490908         True
# PFDAVVNDA.CL       24200.0       23078.0   23361.327786         True
# PFGRUPOARG.CL      10880.0  13611.774219   12847.698889        False
# PFGRUPSURA.CL      35640.0  37559.778125   36949.510658        False
# PROMIGAS.CL         6740.0   6625.758984    6635.704334         True
# TERPEL.CL          14480.0       13190.0    13441.89614         True
# AAPL            232.139999    217.212679     219.761574         True
# AMZN                 229.0    225.561002      223.50652         True
# BAC              50.740002        47.738      47.495703         True
# BRK-B           502.980011    481.182999     486.036457         True
# C                    96.57     91.528817       90.64787         True
# CBU7.L          141.279999    139.924001     139.981747         True
# CENCOSUD.SN    3063.899902   3058.869995    3060.905023         True
# CHILE.SN        138.539993    138.246001     138.630941         True
# CSPX.L           689.51001    676.034991     673.492528         True
# EIMI.L           40.720001        40.152      39.956362         True
# F                    11.77     11.290947      11.219117         True
# FALABELLA.SN        5503.0    5069.47998     5120.45943         True
# GE              275.200012    264.453641     262.657793         True
# GOOGL           212.910004    192.993999     195.073636         True
# JETS             26.309999        24.662      24.672108         True
# JNJ             175.879028    165.890349     168.093417         True
# JPM             301.420013    292.334421       289.2676         True
# META            738.700012    738.514001     732.298193         True
# NKE              77.370003        75.133      73.964955         True
# NVDA            174.179993    171.695999     169.053383         True
# PBR                   12.4        12.448      12.332799         True
# PFE                  24.76      24.62185      24.575705         True
# SGLD.L          331.899994    323.290997      323.97292         True
# VOO             593.080017    580.942456     578.641707         True
#
#               EMA10 Signal MACD Signal
# BOGOTA.CL             True        True
# BVC.CL                True       False
# CELSIA.CL             True        True
# CEMARGOS.CL          False       False
# CIBEST.CL             True        True
# CNEC.CL               True       False
# CONCONCRET.CL        False       False
# CORFICOLCF.CL         True       False
# ECOPETROL.CL          True        True
# ENKA.CL               True        True
# ETB.CL               False        True
# EXITO.CL              True        True
# GEB.CL                True       False
# GRUBOLIVAR.CL         True        True
# GRUPOARGOS.CL        False       False
# GRUPOAVAL.CL          True        True
# GRUPOSURA.CL          True       False
# HCOLSEL.CL            True        True
# ICOLCAP.CL            True        True
# ISA.CL                True        True
# MINEROS.CL            True        True
# NUTRESA.CL            True        True
# PFAVAL.CL             True        True
# PFCIBEST.CL           True        True
# PFCORFICOL.CL         True        True
# PFDAVVNDA.CL          True        True
# PFGRUPOARG.CL        False       False
# PFGRUPSURA.CL        False       False
# PROMIGAS.CL           True        True
# TERPEL.CL             True        True
# AAPL                  True        True
# AMZN                  True        True
# BAC                   True        True
# BRK-B                 True       False
# C                     True        True
# CBU7.L                True        True
# CENCOSUD.SN           True       False
# CHILE.SN              True       False
# CSPX.L                True        True
# EIMI.L                True        True
# F                     True        True
# FALABELLA.SN          True        True
# GE                    True        True
# GOOGL                 True        True
# JETS                  True        True
# JNJ                   True        True
# JPM                   True        True
# META                  True        True
# NKE                   True        True
# NVDA                  True        True
# PBR                   True        True
# PFE                   True        True
# SGLD.L                True       False
# VOO                   True        True

# %% [markdown]
# ### **Stock filtering by signal**

# %%
signals_filtered = signals[np.int64(signals['MACD Signal']) + np.int64(signals[f'SMA{MA_terms} Signal']) + np.int64(signals[f'EMA{MA_terms} Signal']) >= 2]

# %%
selected_stocks_rets = rets[signals_filtered.index]
selected_stocks_stocks = stocks[signals_filtered.index]

# %%
selected_stocks_rets.index = selected_stocks_rets.index.astype('str').str.split('/').str[1]
selected_stocks_stocks.index = selected_stocks_stocks.index.astype('str').str.split('/').str[1]

rets.index = rets.index.astype('str').str.split('/').str[1]
stocks.index = stocks.index.astype('str').str.split('/').str[1]

# %% [markdown]
# ### **Export datasets and an index for the Sharpe-Ratio maximizing allocation**

# %%
# Selected stocks dataset
selected_stocks_rets.to_csv('selected_stocks_rets.csv')
selected_stocks_stocks.to_csv('selected_stocks_stocks.csv')

# Concatenated returns and stock prices datasets
rets.to_csv('all_rets.csv')
stocks.to_csv('all_stocks.csv')
