# %% [markdown]
# ### **Load libraries**

# %%
import sys
sys.path.append('../src')
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import risk_kit as rk
import tensorflow as tf
from tensorflow.keras.layers import Layer, Dense, LayerNormalization, Dropout
import importlib

import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.api import VAR
from mgarch import mgarch

import itertools
import random

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# ### **Load data**

# %%
rets = pd.read_csv('../temp_references/all_rets.csv', index_col=0)
stocks = pd.read_csv('../temp_references/all_stocks.csv', index_col=0)
selected_stocks = pd.read_csv('../temp_references/selected_stocks_rets.csv', index_col=0).columns

rets.index = pd.to_datetime(rets.index).to_period('W')
stocks.index = pd.to_datetime(stocks.index).to_period('W')

# %%
# Define the number of periods per year for all calculations
# 252 is an approximation for daily
# 54 for weekly
# 12 for monthly
periods_per_year = 54

# %%
rets_backup = rets.copy(); stocks_backup = stocks.copy()

# Determine the dataset size
# Uncomment if a smaller dataset is desired
# rets = rets.loc['2021-01-01':]
# stocks = stocks.loc['2021-01-01':]

# %% [markdown]
# # **Estimation of future Moving Average Returns**

# %% [markdown]
# ## **Analysis of stationarity**

# %%
# Analysis of stationarity for the whole series
for stock in rets.columns:
    print(f'Augmented Dickey Fuller Test p-value for non-stationarity of level {stock} series: {round(adfuller(rets[stock])[1], 4)}')

# All return series are stationary, however, differentiating by first order seems to result in better models
# Out:
# Augmented Dickey Fuller Test p-value for non-stationarity of level BOGOTA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level BVC.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CELSIA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CEMARGOS.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CIBEST.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CNEC.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CONCONCRET.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CORFICOLCF.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ECOPETROL.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ENKA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ETB.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level EXITO.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level GEB.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level GRUBOLIVAR.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level GRUPOARGOS.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level GRUPOAVAL.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level GRUPOSURA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level HCOLSEL.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ICOLCAP.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ISA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level MINEROS.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level NUTRESA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PFAVAL.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PFCIBEST.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PFCORFICOL.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PFDAVVNDA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PFGRUPOARG.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PFGRUPSURA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PROMIGAS.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level TERPEL.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level AAPL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level AGUAS-A.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level AMZN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ANDINA-B.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level BAC series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level BAP series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level BRK-B series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level BSANTANDER.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level BVN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level C series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CBU7.L series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CENCOSUD.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CFMITNIPSA.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CHILE.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level COLBUN.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CONCHATORO.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level COPEC.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CPAC series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CSPX.L series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ECL.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level EIMI.L series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ENELCHILE.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ENTEL.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level F series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level FALABELLA.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level GE series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level GOOGL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level IAM.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level IJPA.L series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ITAUCL.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level JETS series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level JNJ series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level JPM series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level META series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level NKE series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level NVDA series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PARAUCO.SN series: 0.0001
# Augmented Dickey Fuller Test p-value for non-stationarity of level PBR series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level PFE series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level RIPLEY.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level SCCO series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level SGLD.L series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level SMU.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level SPXS.L series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level SUAS.L series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level URA series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level VAPORES.SN series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level VOLCABC1.LM series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level VOO series: 0.0

# %% [markdown]
# ## **Model 1: Annualized Yearly Returns from the Last 3 Years**

# %%
# Compare with the expected returns calculated from historical returns
historical_annualized_returns = rk.summary_stats(rets.iloc[-162:], periods_per_year=periods_per_year)['Annualized Return']
historical_annualized_returns
# Out:
# BOGOTA.CL        0.179984
# BVC.CL           0.331144
# CELSIA.CL        0.309715
# CEMARGOS.CL      0.633388
# CIBEST.CL        0.362080
# CNEC.CL         -0.490924
# CONCONCRET.CL    0.255567
# CORFICOLCF.CL    0.090435
# ECOPETROL.CL     0.095054
# ENKA.CL         -0.111051
# ETB.CL          -0.278098
# EXITO.CL         0.105320
# GEB.CL           0.362533
# GRUBOLIVAR.CL    0.234909
# GRUPOARGOS.CL    0.233262
# GRUPOAVAL.CL     0.162605
# GRUPOSURA.CL     0.145231
# HCOLSEL.CL       0.250958
# ICOLCAP.CL       0.228967
# ISA.CL           0.187420
# MINEROS.CL       1.056421
# NUTRESA.CL       0.729944
# PFAVAL.CL        0.171716
# PFCIBEST.CL      0.403820
# PFCORFICOL.CL    0.146066
# PFDAVVNDA.CL    -0.004489
# PFGRUPOARG.CL    0.442243
# PFGRUPSURA.CL    0.664066
# PROMIGAS.CL      0.223362
# TERPEL.CL        0.426219
# AAPL             0.244017
# AGUAS-A.SN       0.326647
# AMZN             0.250309
# ANDINA-B.SN      0.462467
# BAC              0.184474
# BAP              0.279732
# BRK-B            0.220646
# BSANTANDER.SN    0.343043
# BVN              0.558512
# C                0.382203
# CBU7.L           0.054273
# CCU              0.114654
# CENCOSUD.SN      0.382817
# CFMITNIPSA.SN    0.178493
# CHILE.SN         0.339623
# COLBUN.SN        0.187011
# CONCHATORO.SN    0.033968
# COPEC.SN         0.018578
# CPAC             0.201995
# CSPX.L           0.242911
# ECL.SN           0.387713
# EIMI.L           0.196469
# ENELCHILE.SN     0.419856
# ENTEL.SN         0.256092
# F                0.118147
# FALABELLA.SN     0.521778
# GE               0.883181
# GOOGL            0.471747
# IAM.SN           0.471837
# IJPA.L           0.215009
# ITAUCL.SN        0.329078
# JETS             0.162898
# JNJ              0.105834
# JPM              0.402362
# META             0.711636
# NKE             -0.084408
# NVDA             1.422456
# PARAUCO.SN       0.613212
# PBR              0.131703
# PFE             -0.117623
# RIPLEY.SN        0.477998
# SCCO             0.475743
# SGLD.L           0.366699
# SMU.SN           0.279398
# SPXS.L           0.245593
# SUAS.L           0.181016
# URA              0.344766
# VAPORES.SN      -0.099975
# VOLCABC1.LM      0.018872
# VOO              0.240292
# Name: Annualized Return, dtype: float64

# %% [markdown]
# ## **Model 2: VAR bagging**

# %%
# Get the 1st order integration for the returns series
rets_integrated = (rets - rets.shift(1)).dropna()

# %%
symbols_list = list(rets.columns.values) # List of all available stock symbols
n_iterations = 2000 # The number of iterations of VAR models to perform
set_size = 10 # Number of symbols modeled in each iteration
periods_to_forecast = 4 # Number of periods to forecast

# Initialize an empty list of sets of stock symbols
iterations_symbols = []

for i in range(n_iterations):
    # For each iteration of the model, select a random set of 'set_size' stock symbols
    iterations_symbols.append(random.sample(symbols_list, set_size))

# %%
# Initialize a dictionary of dictionaries where the results of each iteration will be stored
prediction_results = {symbol: {} for symbol in symbols_list}

for i, symbols_selection in enumerate(iterations_symbols):
    # In each iteration, generate a dataset with the stocks selected for the iteration only
    subset_df = rets_integrated[symbols_selection]
    
    # Compare the IC (Information Criteria) scores for VAR models of various number of lags to select the ideal number of lags
    varmod = VAR(subset_df)
    lag_sel = varmod.select_order(10)
    
    # Select the best number of lags according to the AIC criterion
    n_lags = lag_sel.aic
    print(f'Iteration {i}, ideal_n_lags: {n_lags}')
    
    # Fit the model for the iteration
    var_model = VAR(subset_df).fit(maxlags=n_lags, trend='c')

    # Predict the following 'periods_to_forecast' periods
    predictions = var_model.forecast(subset_df.iloc[-n_lags:].values, periods_to_forecast)
    predictions = pd.DataFrame(predictions)

    # Append the predicted values to the 'prediction_results' dictionary
    for l in predictions:
        prediction_results[symbols_selection[l]][i] = predictions[l]
    print(f'Iteration {i+1} finished')
# Out:
# Iteration 0, ideal_n_lags: 9
# Iteration 1 finished
# Iteration 1, ideal_n_lags: 6
# Iteration 2 finished
# Iteration 2, ideal_n_lags: 7
# Iteration 3 finished
# Iteration 3, ideal_n_lags: 10
# Iteration 4 finished
# Iteration 4, ideal_n_lags: 8
# Iteration 5 finished
# Iteration 5, ideal_n_lags: 8
# Iteration 6 finished
# Iteration 6, ideal_n_lags: 7
# Iteration 7 finished
# Iteration 7, ideal_n_lags: 10
# Iteration 8 finished
# Iteration 8, ideal_n_lags: 7
# Iteration 9 finished
# Iteration 9, ideal_n_lags: 10
# Iteration 10 finished
# Iteration 10, ideal_n_lags: 8
# Iteration 11 finished
# Iteration 11, ideal_n_lags: 7
# Iteration 12 finished
# Iteration 12, ideal_n_lags: 10
# Iteration 13 finished
# Iteration 13, ideal_n_lags: 8
# Iteration 14 finished
# Iteration 14, ideal_n_lags: 8
# Iteration 15 finished
# Iteration 15, ideal_n_lags: 7
# Iteration 16 finished
# Iteration 16, ideal_n_lags: 8
# Iteration 17 finished
# Iteration 17, ideal_n_lags: 9
# Iteration 18 finished
# Iteration 18, ideal_n_lags: 8
# Iteration 19 finished
# Iteration 19, ideal_n_lags: 8
# Iteration 20 finished
# Iteration 20, ideal_n_lags: 9
# Iteration 21 finished
# Iteration 21, ideal_n_lags: 6
# Iteration 22 finished
# Iteration 22, ideal_n_lags: 9
# Iteration 23 finished
# Iteration 23, ideal_n_lags: 9
# Iteration 24 finished
# Iteration 24, ideal_n_lags: 8
# Iteration 25 finished
# Iteration 25, ideal_n_lags: 8
# Iteration 26 finished
# Iteration 26, ideal_n_lags: 8
# Iteration 27 finished
# Iteration 27, ideal_n_lags: 8
# Iteration 28 finished
# Iteration 28, ideal_n_lags: 7
# Iteration 29 finished
# Iteration 29, ideal_n_lags: 6
# Iteration 30 finished
# Iteration 30, ideal_n_lags: 8
# Iteration 31 finished
# Iteration 31, ideal_n_lags: 10
# Iteration 32 finished
# Iteration 32, ideal_n_lags: 8
# Iteration 33 finished
# Iteration 33, ideal_n_lags: 8
# Iteration 34 finished
# Iteration 34, ideal_n_lags: 8
# Iteration 35 finished
# Iteration 35, ideal_n_lags: 7
# Iteration 36 finished
# Iteration 36, ideal_n_lags: 8
# Iteration 37 finished
# Iteration 37, ideal_n_lags: 9
# Iteration 38 finished
# Iteration 38, ideal_n_lags: 8
# Iteration 39 finished
# Iteration 39, ideal_n_lags: 10
# Iteration 40 finished
# Iteration 40, ideal_n_lags: 6
# Iteration 41 finished
# Iteration 41, ideal_n_lags: 7
# Iteration 42 finished
# Iteration 42, ideal_n_lags: 7
# Iteration 43 finished
# Iteration 43, ideal_n_lags: 9
# Iteration 44 finished
# Iteration 44, ideal_n_lags: 8
# Iteration 45 finished
# Iteration 45, ideal_n_lags: 8
# Iteration 46 finished
# Iteration 46, ideal_n_lags: 10
# Iteration 47 finished
# Iteration 47, ideal_n_lags: 8
# Iteration 48 finished
# Iteration 48, ideal_n_lags: 10
# Iteration 49 finished
# Iteration 49, ideal_n_lags: 7
# Iteration 50 finished
# Iteration 50, ideal_n_lags: 10
# Iteration 51 finished
# Iteration 51, ideal_n_lags: 9
# Iteration 52 finished
# Iteration 52, ideal_n_lags: 8
# Iteration 53 finished
# Iteration 53, ideal_n_lags: 7
# Iteration 54 finished
# Iteration 54, ideal_n_lags: 8
# Iteration 55 finished
# Iteration 55, ideal_n_lags: 8
# Iteration 56 finished
# Iteration 56, ideal_n_lags: 8
# Iteration 57 finished
# Iteration 57, ideal_n_lags: 7
# Iteration 58 finished
# Iteration 58, ideal_n_lags: 8
# Iteration 59 finished
# Iteration 59, ideal_n_lags: 9
# Iteration 60 finished
# Iteration 60, ideal_n_lags: 9
# Iteration 61 finished
# Iteration 61, ideal_n_lags: 10
# Iteration 62 finished
# Iteration 62, ideal_n_lags: 7
# Iteration 63 finished
# Iteration 63, ideal_n_lags: 8
# Iteration 64 finished
# Iteration 64, ideal_n_lags: 8
# Iteration 65 finished
# Iteration 65, ideal_n_lags: 8
# Iteration 66 finished
# Iteration 66, ideal_n_lags: 8
# Iteration 67 finished
# Iteration 67, ideal_n_lags: 10
# Iteration 68 finished
# Iteration 68, ideal_n_lags: 8
# Iteration 69 finished
# Iteration 69, ideal_n_lags: 10
# Iteration 70 finished
# Iteration 70, ideal_n_lags: 8
# Iteration 71 finished
# Iteration 71, ideal_n_lags: 8
# Iteration 72 finished
# Iteration 72, ideal_n_lags: 6
# Iteration 73 finished
# Iteration 73, ideal_n_lags: 8
# Iteration 74 finished
# Iteration 74, ideal_n_lags: 9
# Iteration 75 finished
# Iteration 75, ideal_n_lags: 8
# Iteration 76 finished
# Iteration 76, ideal_n_lags: 7
# Iteration 77 finished
# Iteration 77, ideal_n_lags: 8
# Iteration 78 finished
# Iteration 78, ideal_n_lags: 8
# Iteration 79 finished
# Iteration 79, ideal_n_lags: 9
# Iteration 80 finished
# Iteration 80, ideal_n_lags: 7
# Iteration 81 finished
# Iteration 81, ideal_n_lags: 7
# Iteration 82 finished
# Iteration 82, ideal_n_lags: 8
# Iteration 83 finished
# Iteration 83, ideal_n_lags: 7
# Iteration 84 finished
# Iteration 84, ideal_n_lags: 8
# Iteration 85 finished
# Iteration 85, ideal_n_lags: 8
# Iteration 86 finished
# Iteration 86, ideal_n_lags: 8
# Iteration 87 finished
# Iteration 87, ideal_n_lags: 8
# Iteration 88 finished
# Iteration 88, ideal_n_lags: 8
# Iteration 89 finished
# Iteration 89, ideal_n_lags: 8
# Iteration 90 finished
# Iteration 90, ideal_n_lags: 8
# Iteration 91 finished
# Iteration 91, ideal_n_lags: 8
# Iteration 92 finished
# Iteration 92, ideal_n_lags: 10
# Iteration 93 finished
# Iteration 93, ideal_n_lags: 9
# Iteration 94 finished
# Iteration 94, ideal_n_lags: 7
# Iteration 95 finished
# Iteration 95, ideal_n_lags: 8
# Iteration 96 finished
# Iteration 96, ideal_n_lags: 7
# Iteration 97 finished
# Iteration 97, ideal_n_lags: 8
# Iteration 98 finished
# Iteration 98, ideal_n_lags: 7
# Iteration 99 finished
# Iteration 99, ideal_n_lags: 8
# Iteration 100 finished
# Iteration 100, ideal_n_lags: 8
# Iteration 101 finished
# Iteration 101, ideal_n_lags: 9
# Iteration 102 finished
# Iteration 102, ideal_n_lags: 7
# Iteration 103 finished
# Iteration 103, ideal_n_lags: 8
# Iteration 104 finished
# Iteration 104, ideal_n_lags: 10
# Iteration 105 finished
# Iteration 105, ideal_n_lags: 9
# Iteration 106 finished
# Iteration 106, ideal_n_lags: 8
# Iteration 107 finished
# Iteration 107, ideal_n_lags: 10
# Iteration 108 finished
# Iteration 108, ideal_n_lags: 8
# Iteration 109 finished
# Iteration 109, ideal_n_lags: 10
# Iteration 110 finished
# Iteration 110, ideal_n_lags: 8
# Iteration 111 finished
# Iteration 111, ideal_n_lags: 8
# Iteration 112 finished
# Iteration 112, ideal_n_lags: 8
# Iteration 113 finished
# Iteration 113, ideal_n_lags: 10
# Iteration 114 finished
# Iteration 114, ideal_n_lags: 6
# Iteration 115 finished
# Iteration 115, ideal_n_lags: 8
# Iteration 116 finished
# Iteration 116, ideal_n_lags: 8
# Iteration 117 finished
# Iteration 117, ideal_n_lags: 10
# Iteration 118 finished
# Iteration 118, ideal_n_lags: 8
# Iteration 119 finished
# Iteration 119, ideal_n_lags: 9
# Iteration 120 finished
# Iteration 120, ideal_n_lags: 8
# Iteration 121 finished
# Iteration 121, ideal_n_lags: 10
# Iteration 122 finished
# Iteration 122, ideal_n_lags: 10
# Iteration 123 finished
# Iteration 123, ideal_n_lags: 9
# Iteration 124 finished
# Iteration 124, ideal_n_lags: 8
# Iteration 125 finished
# Iteration 125, ideal_n_lags: 8
# Iteration 126 finished
# Iteration 126, ideal_n_lags: 10
# Iteration 127 finished
# Iteration 127, ideal_n_lags: 10
# Iteration 128 finished
# Iteration 128, ideal_n_lags: 7
# Iteration 129 finished
# Iteration 129, ideal_n_lags: 9
# Iteration 130 finished
# Iteration 130, ideal_n_lags: 10
# Iteration 131 finished
# Iteration 131, ideal_n_lags: 8
# Iteration 132 finished
# Iteration 132, ideal_n_lags: 10
# Iteration 133 finished
# Iteration 133, ideal_n_lags: 10
# Iteration 134 finished
# Iteration 134, ideal_n_lags: 8
# Iteration 135 finished
# Iteration 135, ideal_n_lags: 7
# Iteration 136 finished
# Iteration 136, ideal_n_lags: 8
# Iteration 137 finished
# Iteration 137, ideal_n_lags: 8
# Iteration 138 finished
# Iteration 138, ideal_n_lags: 9
# Iteration 139 finished
# Iteration 139, ideal_n_lags: 8
# Iteration 140 finished
# Iteration 140, ideal_n_lags: 8
# Iteration 141 finished
# Iteration 141, ideal_n_lags: 7
# Iteration 142 finished
# Iteration 142, ideal_n_lags: 10
# Iteration 143 finished
# Iteration 143, ideal_n_lags: 10
# Iteration 144 finished
# Iteration 144, ideal_n_lags: 8
# Iteration 145 finished
# Iteration 145, ideal_n_lags: 8
# Iteration 146 finished
# Iteration 146, ideal_n_lags: 10
# Iteration 147 finished
# Iteration 147, ideal_n_lags: 7
# Iteration 148 finished
# Iteration 148, ideal_n_lags: 8
# Iteration 149 finished
# Iteration 149, ideal_n_lags: 10
# Iteration 150 finished
# Iteration 150, ideal_n_lags: 7
# Iteration 151 finished
# Iteration 151, ideal_n_lags: 8
# Iteration 152 finished
# Iteration 152, ideal_n_lags: 7
# Iteration 153 finished
# Iteration 153, ideal_n_lags: 9
# Iteration 154 finished
# Iteration 154, ideal_n_lags: 10
# Iteration 155 finished
# Iteration 155, ideal_n_lags: 8
# Iteration 156 finished
# Iteration 156, ideal_n_lags: 10
# Iteration 157 finished
# Iteration 157, ideal_n_lags: 8
# Iteration 158 finished
# Iteration 158, ideal_n_lags: 8
# Iteration 159 finished
# Iteration 159, ideal_n_lags: 8
# Iteration 160 finished
# Iteration 160, ideal_n_lags: 8
# Iteration 161 finished
# Iteration 161, ideal_n_lags: 9
# Iteration 162 finished
# Iteration 162, ideal_n_lags: 8
# Iteration 163 finished
# Iteration 163, ideal_n_lags: 10
# Iteration 164 finished
# Iteration 164, ideal_n_lags: 8
# Iteration 165 finished
# Iteration 165, ideal_n_lags: 7
# Iteration 166 finished
# Iteration 166, ideal_n_lags: 8
# Iteration 167 finished
# Iteration 167, ideal_n_lags: 8
# Iteration 168 finished
# Iteration 168, ideal_n_lags: 8
# Iteration 169 finished
# Iteration 169, ideal_n_lags: 10
# Iteration 170 finished
# Iteration 170, ideal_n_lags: 6
# Iteration 171 finished
# Iteration 171, ideal_n_lags: 8
# Iteration 172 finished
# Iteration 172, ideal_n_lags: 10
# Iteration 173 finished
# Iteration 173, ideal_n_lags: 8
# Iteration 174 finished
# Iteration 174, ideal_n_lags: 7
# Iteration 175 finished
# Iteration 175, ideal_n_lags: 8
# Iteration 176 finished
# Iteration 176, ideal_n_lags: 6
# Iteration 177 finished
# Iteration 177, ideal_n_lags: 8
# Iteration 178 finished
# Iteration 178, ideal_n_lags: 7
# Iteration 179 finished
# Iteration 179, ideal_n_lags: 8
# Iteration 180 finished
# Iteration 180, ideal_n_lags: 7
# Iteration 181 finished
# Iteration 181, ideal_n_lags: 10
# Iteration 182 finished
# Iteration 182, ideal_n_lags: 8
# Iteration 183 finished
# Iteration 183, ideal_n_lags: 8
# Iteration 184 finished
# Iteration 184, ideal_n_lags: 9
# Iteration 185 finished
# Iteration 185, ideal_n_lags: 8
# Iteration 186 finished
# Iteration 186, ideal_n_lags: 8
# Iteration 187 finished
# Iteration 187, ideal_n_lags: 8
# Iteration 188 finished
# Iteration 188, ideal_n_lags: 7
# Iteration 189 finished
# Iteration 189, ideal_n_lags: 8
# Iteration 190 finished
# Iteration 190, ideal_n_lags: 9
# Iteration 191 finished
# Iteration 191, ideal_n_lags: 8
# Iteration 192 finished
# Iteration 192, ideal_n_lags: 7
# Iteration 193 finished
# Iteration 193, ideal_n_lags: 8
# Iteration 194 finished
# Iteration 194, ideal_n_lags: 9
# Iteration 195 finished
# Iteration 195, ideal_n_lags: 8
# Iteration 196 finished
# Iteration 196, ideal_n_lags: 8
# Iteration 197 finished
# Iteration 197, ideal_n_lags: 8
# Iteration 198 finished
# Iteration 198, ideal_n_lags: 8
# Iteration 199 finished
# Iteration 199, ideal_n_lags: 8
# Iteration 200 finished
# Iteration 200, ideal_n_lags: 8
# Iteration 201 finished
# Iteration 201, ideal_n_lags: 8
# Iteration 202 finished
# Iteration 202, ideal_n_lags: 10
# Iteration 203 finished
# Iteration 203, ideal_n_lags: 8
# Iteration 204 finished
# Iteration 204, ideal_n_lags: 9
# Iteration 205 finished
# Iteration 205, ideal_n_lags: 8
# Iteration 206 finished
# Iteration 206, ideal_n_lags: 8
# Iteration 207 finished
# Iteration 207, ideal_n_lags: 8
# Iteration 208 finished
# Iteration 208, ideal_n_lags: 10
# Iteration 209 finished
# Iteration 209, ideal_n_lags: 9
# Iteration 210 finished
# Iteration 210, ideal_n_lags: 8
# Iteration 211 finished
# Iteration 211, ideal_n_lags: 8
# Iteration 212 finished
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 10
#       8 # Compare the IC (Information Criteria) scores for VAR models of various number of lags to select the ideal number of lags
#       9 varmod = VAR(subset_df)
# ---> 10 lag_sel = varmod.select_order(10)
#      12 # Select the best number of lags according to the AIC criterion
#      13 n_lags = lag_sel.aic
#
# File C:\Python projects\Finance\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py:821, in VAR.select_order(self, maxlags, trend)
#     817 p_min = 0 if self.exog is not None or trend != "n" else 1
#     818 for p in range(p_min, maxlags + 1):
#     819     # exclude some periods to same amount of data used for each lag
#     820     # order
# --> 821     result = self._estimate_var(p, offset=maxlags - p, trend=trend)
#     823     for k, v in result.info_criteria.items():
#     824         ics[k].append(v)
#
# File C:\Python projects\Finance\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py:742, in VAR._estimate_var(self, lags, offset, trend)
#     740 y_sample = endog[lags:]
#     741 # Lütkepohl p75, about 5x faster than stated formula
# --> 742 params = np.linalg.lstsq(z, y_sample, rcond=1e-15)[0]
#     743 resid = y_sample - np.dot(z, params)
#     745 # Unbiased estimate of covariance matrix $\Sigma_u$ of the white noise
#     746 # process $u$
#     747 # equivalent definition
#    (...)
#     750 # Ref: Lütkepohl p.75
#     751 # df_resid right now is T - Kp - 1, which is a suggested correction
#
# File C:\Python projects\Finance\lib\site-packages\numpy\linalg\linalg.py:2326, in lstsq(a, b, rcond)
#    2323 if n_rhs == 0:
#    2324     # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2325     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2326 x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2327 if m == 0:
#    2328     x[...] = 0
#
# KeyboardInterrupt:

# %%
import warnings
warnings.filterwarnings('ignore')

# Copy the 'prediction_results' dictionary to invert the integration of the copy and set the index for predicted dates
prediction_results_processed = prediction_results.copy()
for symbol in prediction_results:
    # For each stock in 'prediction_results', convert the predictions into a dataframe
    pred_df = pd.DataFrame(prediction_results[symbol])

    # Get the average predictions for each day
    pred_series = pred_df.mean(axis=1)

    # Invert the integration by taking the last actual returns and add it to the predictions, then do a cumulative sum
    pred_series = rets[symbol][-1] + pred_series.cumsum()
    
    # Generate an index for the future dates
    #future_dates = pd.date_range(start=rets.index.max().to_timestamp() + pd.Timedelta(value=1, unit='d'), periods=periods_to_forecast)
    future_dates = pd.date_range(start=rets.index.max().to_timestamp() + pd.Timedelta(value=7, unit='d'), periods=periods_to_forecast, freq='W-SUN').to_period('W') # Weekly
    pred_series.index = future_dates
    
    # Add the series of average predicted returns for the stock to the 'prediction_results_processed' dictionary
    prediction_results_processed[symbol] = pred_series

# %%
# Visualize the predictions of any stock
symbol = 'PFGRUPSURA.CL'
concat_df = pd.concat([rets[symbol][-50:], pd.DataFrame(prediction_results_processed[symbol], columns=[symbol])], axis=1)

concat_df.plot()
#prediction_results_processed[symbol].plot()
plt.grid(alpha=.4)
plt.title(symbol)
plt.show()

# %%
# Calculate the exptected annual returns for each stock
# Initialize an empty dictionary where the returns will be stored
expected_annualized_rets = {}

for symbol in prediction_results_processed:
    # Calculate the weighted average returns from the predictions and then annualize them
    # Uncomment the method of weighting for the averaging and annualization of the returns
    
    ### Raw predicted returns annualized
    # expected_annualized_returns = ((prediction_results_processed[symbol] + 1).prod()**(1/len(prediction_results_processed[symbol])))**(periods_per_year) - 1
    
    ### Linearly decaying weighted returns annualized
    # weight_indexes = np.array([i+1 for i in range(periods_to_forecast)])
    # linear_decay_w = (periods_to_forecast - weight_indexes + 1)/weight_indexes.sum()
    # expected_annualized_returns = (1 + np.sum(prediction_results_processed[symbol]*linear_decay_w))**periods_per_year - 1

    ### Exponentially decaying weighted returns annualized
    weight_indexes = np.array([i+1 for i in range(periods_to_forecast)])
    lambda_ = 0.2
    exponential_decay_w = np.exp(-lambda_*weight_indexes)/np.exp(-lambda_*weight_indexes).sum()
    expected_annualized_returns = (1 + np.sum(prediction_results_processed[symbol]*exponential_decay_w))**periods_per_year - 1

    expected_annualized_rets[symbol] = expected_annualized_returns

# %%
# Predictions of annualized returns for the VAR Bagging model
var_bagging_expected_annualized_rets = expected_annualized_rets
pd.Series(var_bagging_expected_annualized_rets)

# %% [markdown]
# ## **Model 3: Transformer Neural Network**

# %% [markdown]
# ### **Generate the data**

# %%
data = rets.values

# Prepare the data for training
def create_dataset(data, time_window=1):
    X, Y = [], []

    for i in range(len(data)-time_window):
        X.append(data[i:(i+time_window)])
        Y.append(data[i + time_window])
    return np.array(X), np.array(Y)

# Generate the sequences of data
time_window = 54
X, Y = create_dataset(data, time_window)

print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)
# Out:
# Shape of X: (468, 54, 79)
# Shape of Y: (468, 79)

# %% [markdown]
# ### **Implement Positional Encoding**

# %%
# Positional encoding represents the data in time steps
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, sequence_length, d_model):
        super().__init__()
        self.sequence_length = sequence_length
        self.d_model = d_model

    def call(self, inputs):
        positions = np.arange(self.sequence_length)[:, np.newaxis]
        # Calculate div_term for even indices only (half of d_model, rounded up)
        num_encoding_dims = (self.d_model + 1) // 2
        div_term = np.exp(np.arange(0, num_encoding_dims) * (-np.log(10000.0) / self.d_model))
        pos_encoding = np.zeros((self.sequence_length, self.d_model))
        # Assign sin to even indices
        pos_encoding[:, 0::2] = np.sin(positions * div_term)
        # Assign cos to odd indices (only up to the number of odd indices available)
        pos_encoding[:, 1::2] = np.cos(positions * div_term[:self.d_model//2])
        return inputs + tf.convert_to_tensor(pos_encoding, dtype=tf.float32)

# %% [markdown]
# ### **Implement the Transformer Encoder block**

# %%
# Implement Multi-Head Self-Attention, Layer Normalization, and Feed-Forward Networks
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.1):
    # Multi-Head Self-Attention
    x = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=head_size, dropout=dropout)(inputs, inputs)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x + inputs)

    # Feed-Forward Network
    ff_output = tf.keras.layers.Dense(ff_dim, activation="relu")(x)
    ff_output = tf.keras.layers.Dense(inputs.shape[-1])(ff_output)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x + ff_output)

    return x

# %% [markdown]
# ### **Build the Transformer Model**

# %%
# Function that builds the model that will take inputs, encode them, and then make a prediction for the input_shape[1] items
def build_transformer_model(input_shape, head_size=64, num_heads=4, ff_dim=128, num_transformer_blocks=2, dropout=0.1):
    inputs = tf.keras.layers.Input(shape=input_shape)
    
    # Positional Encoding
    x = PositionalEncoding(sequence_length=input_shape[0], d_model=input_shape[1])(inputs)
    
    # Transformer Encoder Blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)
    
    # Global Average Pooling over time dimension
    x = tf.keras.layers.GlobalAveragePooling1D()(x)

    # Output Layer (input_shape[1]-dimensional vector)
    outputs = tf.keras.layers.Dense(input_shape[1])(x)

    # Build Model
    model = tf.keras.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss="mse",
        metrics=["mae", tf.keras.metrics.RootMeanSquaredError]
    )
    
    return model

# %% [markdown]
# ### **Train the Model**

# %%
input_shape = (time_window, X.shape[2]) # Shape of each input
head_size = 128
num_heads = 8
ff_dim = 512
num_transformer_blocks = 6
dropout = 0.1

model = build_transformer_model(input_shape)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Python projects\Finance\lib\site-packages\keras\src\backend\tensorflow\core.py:219: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 54, 79)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ positional_encoding           │ (None, 54, 79)            │               0 │ input_layer[0][0]          │
# │ (PositionalEncoding)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 54, 79)            │          81,743 │ positional_encoding[0][0], │
# │ (MultiHeadAttention)          │                           │                 │ positional_encoding[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 54, 79)            │               0 │ multi_head_attention[0][0… │
# │                               │                           │                 │ positional_encoding[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization           │ (None, 54, 79)            │             158 │ add[0][0]                  │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 54, 128)           │          10,240 │ layer_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 54, 79)            │          10,191 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 54, 79)            │               0 │ layer_normalization[0][0], │
# │                               │                           │                 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_1         │ (None, 54, 79)            │             158 │ add_1[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 54, 79)            │          81,743 │ layer_normalization_1[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 54, 79)            │               0 │ multi_head_attention_1[0]… │
# │                               │                           │                 │ layer_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_2         │ (None, 54, 79)            │             158 │ add_2[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 54, 128)           │          10,240 │ layer_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 54, 79)            │          10,191 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 54, 79)            │               0 │ layer_normalization_2[0][… │
# │                               │                           │                 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_3         │ (None, 54, 79)            │             158 │ add_3[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 79)                │               0 │ layer_normalization_3[0][… │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 79)                │           6,320 │ global_average_pooling1d[… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 211,300 (825.39 KB)
#  Trainable params: 211,300 (825.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    X, Y,
    epochs=50,
    batch_size=32
)
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.2560 - mae: 0.3928 - root_mean_squared_error: 0.5035
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0019 - mae: 0.0290 - root_mean_squared_error: 0.0441

# %% [markdown]
# ### **Perform predictions**

# %%
# Generate the input for the prediction of future period

# Add a dummy array for the future period,
# so that the generate_dataset function will capture the latest observation in the last sequence
data_preds = data.copy()
data_preds = np.concatenate((data_preds, np.expand_dims(np.zeros_like(data_preds[-1]), axis=0)))

X_, Y_ = create_dataset(data_preds, time_window)

# %%
periods_to_forecast = 4
preds = []
pred_inputs = np.expand_dims(X_[-1], axis=0)

for i in range(periods_to_forecast):
    prediction = model.predict(pred_inputs)
    preds.append(prediction[0])
    pred_inputs = np.concatenate((pred_inputs[0][1:], np.expand_dims(prediction[0], axis=0)))
    pred_inputs = np.expand_dims(pred_inputs, axis=0)

preds = np.array(preds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
preds_df = pd.DataFrame(preds, columns=rets.columns)

future_dates = pd.date_range(start=rets.index.max().to_timestamp() + pd.Timedelta(value=7, unit='d'), periods=periods_to_forecast, freq='W-SUN').to_period('W') # Weekly
preds_df = pd.DataFrame(preds, columns=rets.columns, index=future_dates)

# %%
# Visualize the predictions of any stock
symbol = 'NVDA'#'PFGRUPSURA.CL'
concat_df = pd.concat([rets[symbol][-50:], preds_df[symbol]], axis=1)

concat_df.plot()
#prediction_results_processed[symbol].plot()
plt.grid(alpha=.4)
plt.title(symbol)
plt.show()

# %%
# Calculate the exptected annual returns for each stock
# Initialize an empty dictionary where the returns will be stored
expected_annualized_rets = {}

for symbol in preds_df.columns:
    # Calculate the weighted average returns from the predictions and then annualize them
    # Uncomment the method of weighting for the averaging and annualization of the returns
    
    ### Raw predicted returns annualized
    # expected_annualized_returns = ((prediction_results_processed[symbol] + 1).prod()**(1/len(prediction_results_processed[symbol])))**(periods_per_year) - 1
    
    ### Linearly decaying weighted returns annualized
    # weight_indexes = np.array([i+1 for i in range(periods_to_forecast)])
    # linear_decay_w = (periods_to_forecast - weight_indexes + 1)/weight_indexes.sum()
    # expected_annualized_returns = (1 + np.sum(prediction_results_processed[symbol]*linear_decay_w))**periods_per_year - 1

    ### Exponentially decaying weighted returns annualized
    weight_indexes = np.array([i+1 for i in range(periods_to_forecast)])
    lambda_ = 0.2
    exponential_decay_w = np.exp(-lambda_*weight_indexes)/np.exp(-lambda_*weight_indexes).sum()
    expected_annualized_returns = (1 + np.sum(preds_df[symbol]*exponential_decay_w))**periods_per_year - 1

    expected_annualized_rets[symbol] = expected_annualized_returns

# %%
# Predictions of annualized returns for the Transformer model
transformer_expected_annualized_rets = expected_annualized_rets
pd.Series(transformer_expected_annualized_rets).sort_values(ascending=False)
# Out:
# CHILE.SN         3.035999
# ITAUCL.SN        2.842808
# NUTRESA.CL       2.445557
# MINEROS.CL       1.986490
# COLBUN.SN        1.780883
# PFGRUPOARG.CL    1.652856
# ENKA.CL          1.593050
# GRUPOSURA.CL     1.532888
# CBU7.L           1.352775
# ENTEL.SN         1.128650
# PBR              1.105071
# F                0.854451
# GRUBOLIVAR.CL    0.671314
# C                0.648365
# PFE              0.637480
# ICOLCAP.CL       0.632624
# BVN              0.629293
# CELSIA.CL        0.612209
# VOLCABC1.LM      0.608431
# CONCONCRET.CL    0.562241
# SCCO             0.560310
# COPEC.SN         0.548688
# ECOPETROL.CL     0.520329
# SUAS.L           0.488221
# PARAUCO.SN       0.421962
# BAP              0.410573
# GRUPOAVAL.CL     0.390730
# BAC              0.332531
# CPAC             0.258046
# GE               0.252642
# AMZN             0.250563
# PROMIGAS.CL      0.243969
# JPM              0.221306
# BOGOTA.CL        0.195677
# PFAVAL.CL        0.190657
# TERPEL.CL        0.131225
# SGLD.L           0.130562
# EIMI.L           0.085488
# CNEC.CL          0.067387
# ENELCHILE.SN     0.065608
# NVDA             0.034030
# GEB.CL           0.033817
# JETS             0.003182
# CFMITNIPSA.SN   -0.017457
# IJPA.L          -0.019057
# NKE             -0.032382
# GRUPOARGOS.CL   -0.048349
# CORFICOLCF.CL   -0.060211
# AAPL            -0.090175
# ECL.SN          -0.097540
# PFCIBEST.CL     -0.114642
# META            -0.115058
# URA             -0.167017
# SMU.SN          -0.175110
# VOO             -0.175230
# EXITO.CL        -0.176157
# JNJ             -0.178912
# CSPX.L          -0.179874
# BRK-B           -0.196817
# ISA.CL          -0.226180
# ETB.CL          -0.227355
# VAPORES.SN      -0.240014
# RIPLEY.SN       -0.254192
# BVC.CL          -0.260638
# PFGRUPSURA.CL   -0.277439
# CONCHATORO.SN   -0.309716
# CIBEST.CL       -0.311436
# PFDAVVNDA.CL    -0.323124
# CEMARGOS.CL     -0.342225
# PFCORFICOL.CL   -0.362901
# SPXS.L          -0.409961
# FALABELLA.SN    -0.410609
# CENCOSUD.SN     -0.441415
# HCOLSEL.CL      -0.456690
# AGUAS-A.SN      -0.499039
# ANDINA-B.SN     -0.526752
# IAM.SN          -0.533132
# GOOGL           -0.550438
# BSANTANDER.SN   -0.570708
# dtype: float64

# %%
# Compare returns of different models:
"""
pd.Series(historical_annualized_returns)
pd.Series(var_bagging_expected_annualized_rets)
pd.Series(transformer_expected_annualized_rets)
"""
# Out:
# '\npd.Series(historical_annualized_returns)\npd.Series(var_bagging_expected_annualized_rets)\npd.Series(transformer_expected_annualized_rets)\n'

# %%
# Uncomment the predictions of the model that was preferred
# expected_returns = historical_annualized_returns
# expected_returns = var_bagging_expected_annualized_rets
expected_returns = transformer_expected_annualized_rets

# %% [markdown]
# # **Covariance matrix estimation**

# %% [markdown]
# ## **Model 1: Historical Covariance Matrix from the last 3 years**

# %%
# Simple long-term covariance
covmat = rets[selected_stocks].iloc[-periods_per_year * 3:].cov()
covmat
# Out:
#                 CNEC.CL      AAPL      AMZN       BAC       BAP     BRK-B  \
# CNEC.CL        0.005918  0.000343  0.000200  0.000429  0.000364  0.000166
# AAPL           0.000343  0.001310  0.000651  0.000406  0.000206  0.000166
# AMZN           0.000200  0.000651  0.001573  0.000598  0.000300  0.000216
# BAC            0.000429  0.000406  0.000598  0.001537  0.000639  0.000502
# BAP            0.000364  0.000206  0.000300  0.000639  0.001216  0.000233
# BRK-B          0.000166  0.000166  0.000216  0.000502  0.000233  0.000502
# BVN            0.000405  0.000272  0.000455  0.000454  0.000833  0.000167
# C              0.000486  0.000486  0.000809  0.001337  0.000552  0.000513
# GOOGL          0.000691  0.000062  0.000388  0.000302  0.000530     0.000199
# IJPA.L         0.000616  0.000108  0.000321  0.000325  0.000588     0.000209
# JETS           0.000835 -0.000029  0.000445  0.000488  0.000604     0.000396
# JNJ            0.000084  0.000083  0.000074  0.000085  0.000052     0.000505
# JPM            0.000750 -0.000028  0.000390  0.000403  0.000688     0.000416
# META           0.000775  0.000119  0.000543  0.000472  0.000789    -0.000281
# NKE            0.000741 -0.000013  0.000404  0.000408  0.000288     0.000088
# NVDA           0.001077 -0.000043  0.000762  0.000737  0.001166    -0.000346
# PBR            0.000206  0.000031  0.000076  0.000093  0.000118     0.000330
# PFE            0.000356 -0.000010  0.000167  0.000170  0.000138     0.000430
# SCCO           0.002718  0.000340  0.000506  0.000531  0.001283     0.000901
# SGLD.L         0.000340  0.000423  0.000030  0.000027  0.000285     0.000361
# SPXS.L         0.000506  0.000030  0.000371  0.000373  0.000465     0.000220
# SUAS.L         0.000531  0.000027  0.000373  0.000408  0.000490     0.000252
# URA            0.001283  0.000285  0.000465  0.000490  0.002745     0.000775
# VOLCABC1.LM    0.000901  0.000361  0.000220  0.000252  0.000775     0.005590
# VOO            0.000558  0.000039  0.000360  0.000357  0.000545     0.000199
#
#                     VOO
# CNEC.CL        0.000195
# AAPL           0.000471
# AMZN           0.000578
# BAC            0.000526
# BAP            0.000272
# BRK-B          0.000223
# BVN            0.000328
# C              0.000585
# CBU7.L         0.000005
# CFMITNIPSA.SN  0.000120
# CSPX.L         0.000359
# EIMI.L         0.000293
# F              0.000479
# GOOGL          0.000472
# IJPA.L         0.000315
# JETS           0.000474
# JNJ            0.000080
# JPM            0.000456
# META           0.000625
# NKE            0.000414
# NVDA           0.000871
# PBR            0.000029
# PFE            0.000157
# SCCO           0.000558
# SGLD.L         0.000039
# SPXS.L         0.000360
# SUAS.L         0.000357
# URA            0.000545
# VOLCABC1.LM    0.000199
# VOO            0.000409

# %% [markdown]
# ## **Model 2: Multivariate GARCH**

# %%
"""
# This section is likely to get deprecated as it's extremely slow to run.

summary_stats = rk.summary_stats(rets[selected_stocks], periods_per_year=periods_per_year, riskfree_rate=0)
returns = summary_stats['Annualized Return']

# Recent covariance prediction based on recent days with GARCH model
vol = mgarch('t')
vol.fit(rets[selected_stocks])
nperiods = 4
covmat = vol.predict(nperiods)
covmat = pd.DataFrame(data=covmat['cov'], index=returns.index, columns=returns.index)
"""
# Out:
# "\n# This section is likely to get deprecated as it's extremely slow to run.\n\nsummary_stats = rk.summary_stats(rets[selected_stocks], periods_per_year=periods_per_year, riskfree_rate=0)\nreturns = summary_stats['Annualized Return']\n\n# Recent covariance prediction based on recent days with GARCH model\nvol = mgarch('t')\nvol.fit(rets[selected_stocks])\nnperiods = 4\ncovmat = vol.predict(nperiods)\ncovmat = pd.DataFrame(data=covmat['cov'], index=returns.index, columns=returns.index)\n"

# %% [markdown]
# # **Export predicted returns and covariance matrix**

# %%
pd.Series(expected_annualized_rets)[selected_stocks].to_csv('../temp_references/expected_returns.csv', header=None)

# %%
covmat.to_csv('../temp_references/expected_covmat.csv')
