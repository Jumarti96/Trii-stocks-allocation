# %% [markdown]
# ### **Load libraries**

# %%
import sys
sys.path.append('../src')
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import risk_kit as rk
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import importlib

import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.api import VAR
from mgarch import mgarch

import itertools
import random

# %%
# ── PyTorch GPU & Tensor Core setup ────────────────────────────────────────
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if torch.cuda.is_available():
    print(f"GPU detected: {torch.cuda.get_device_name(0)}")
    torch.set_float32_matmul_precision('high')  # Enable Tensor Cores (TF32)
    print("Tensor Cores enabled (TF32 + AMP acceleration).")
else:
    print("No GPU found — running on CPU. Training will be significantly slower.")
    print("For faster execution, install the CUDA build of PyTorch:")
    print("  pip install torch --index-url https://download.pytorch.org/whl/cu128")
# Out:
# GPU detected: NVIDIA GeForce RTX 4090 Laptop GPU
# Tensor Cores enabled (TF32 + AMP acceleration).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
# Define the number of periods per year for all calculations
# 52 for weekly, 12 for monthly
periods_per_year = 54
interval = '1wk'  # '1wk' for weekly, '1mo' for monthly

# ─── Derived from interval (do not edit) ────────────────────────────────────
period_freq = 'W' if interval == '1wk' else 'M'
date_offset = pd.Timedelta(days=7) if interval == '1wk' else pd.DateOffset(months=1)
future_freq = 'W-SUN' if interval == '1wk' else 'MS'
time_window = periods_per_year   # Transformer input: one full year of history

# %% [markdown]
# ### **Load data**

# %%
rets = pd.read_csv('../temp_references/all_rets.csv', index_col=0)
stocks = pd.read_csv('../temp_references/all_stocks.csv', index_col=0)
selected_stocks = pd.read_csv('../temp_references/selected_stocks_rets.csv', index_col=0).columns

rets.index = pd.to_datetime(rets.index).to_period(period_freq)
stocks.index = pd.to_datetime(stocks.index).to_period(period_freq)

# %%
# Configuration (periods_per_year, interval, and derived variables) is defined above.

# %%
rets_backup = rets.copy(); stocks_backup = stocks.copy()

# Determine the dataset size
# Uncomment if a smaller dataset is desired
# rets = rets.loc['2021-01-01':]
# stocks = stocks.loc['2021-01-01':]

# %% [markdown]
# # **Estimation of future Moving Average Returns**

# %% [markdown]
# ## **Analysis of stationarity**

# %%
# Analysis of stationarity for the whole series
for stock in rets.columns:
    print(f'Augmented Dickey Fuller Test p-value for non-stationarity of level {stock} series: {round(adfuller(rets[stock])[1], 4)}')

# All return series are stationary, however, differentiating by first order seems to result in better models
# Out:
# Augmented Dickey Fuller Test p-value for non-stationarity of level BOGOTA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level BVC.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CELSIA.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CEMARGOS.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CIBEST.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CNEC.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CONCONCRET.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level CORFICOLCF.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ECOPETROL.CL series: 0.0
# Augmented Dickey Fuller Test p-value for non-stationarity of level ENKA.CL series: 0.0
# ...

# %% [markdown]
# ## **Model 1: Annualized Yearly Returns from the Last 3 Years**

# %%
# Compare with the expected returns calculated from historical returns
historical_annualized_returns = rk.summary_stats(rets.iloc[-162:], periods_per_year=periods_per_year)['Annualized Return']
historical_annualized_returns
# Out:
# BOGOTA.CL        0.207680
# BVC.CL           0.448839
# CELSIA.CL        0.416440
# CEMARGOS.CL      0.707370
# CIBEST.CL        0.489668
# CNEC.CL         -0.452533
# CONCONCRET.CL    0.305168
# CORFICOLCF.CL    0.181411
# ECOPETROL.CL     0.180884
# ENKA.CL         -0.053934
# ETB.CL          -0.234927
# EXITO.CL         0.051862
# GEB.CL           0.418677
# GRUBOLIVAR.CL    0.212417
# GRUPOARGOS.CL    0.256546
# GRUPOAVAL.CL     0.205754
# GRUPOSURA.CL     0.220106
# HCOLSEL.CL       0.325054
# ICOLCAP.CL       0.286446
# ISA.CL           0.279410
# MINEROS.CL       0.848234
# NUTRESA.CL       0.829736
# PFAVAL.CL        0.202307
# PFCIBEST.CL      0.471633
# PFCORFICOL.CL    0.265561
# PFDAVVNDA.CL     0.063692
# PFGRUPOARG.CL    0.423150
# PFGRUPSURA.CL    0.706525
# PROMIGAS.CL      0.273635
# TERPEL.CL        0.492132
# AAPL             0.220959
# AGUAS-A.SN       0.234821
# AMZN             0.399131
# ANDINA-B.SN      0.366264
# BAC              0.247155
# ...

# %% [markdown]
# ## **Model 2: VAR bagging**

# %%
# Get the 1st order integration for the returns series
rets_integrated = (rets - rets.shift(1)).dropna()

# %%
symbols_list = list(rets.columns.values) # List of all available stock symbols
n_iterations = 2000 # The number of iterations of VAR models to perform
set_size = 10 # Number of symbols modeled in each iteration
periods_to_forecast = 4 # Number of periods to forecast

# Initialize an empty list of sets of stock symbols
iterations_symbols = []

for i in range(n_iterations):
    # For each iteration of the model, select a random set of 'set_size' stock symbols
    iterations_symbols.append(random.sample(symbols_list, set_size))

# %%
# Initialize a dictionary of dictionaries where the results of each iteration will be stored
prediction_results = {symbol: {} for symbol in symbols_list}

for i, symbols_selection in enumerate(iterations_symbols):
    # In each iteration, generate a dataset with the stocks selected for the iteration only
    subset_df = rets_integrated[symbols_selection]
    
    # Compare the IC (Information Criteria) scores for VAR models of various number of lags to select the ideal number of lags
    varmod = VAR(subset_df)
    lag_sel = varmod.select_order(10)
    
    # Select the best number of lags according to the AIC criterion
    n_lags = lag_sel.aic
    print(f'Iteration {i}, ideal_n_lags: {n_lags}')
    
    # Fit the model for the iteration
    var_model = VAR(subset_df).fit(maxlags=n_lags, trend='c')

    # Predict the following 'periods_to_forecast' periods
    predictions = var_model.forecast(subset_df.iloc[-n_lags:].values, periods_to_forecast)
    predictions = pd.DataFrame(predictions)

    # Append the predicted values to the 'prediction_results' dictionary
    for l in predictions:
        prediction_results[symbols_selection[l]][i] = predictions[l]
    print(f'Iteration {i+1} finished')
# Out:
# Iteration 0, ideal_n_lags: 8
# Iteration 1 finished
# Iteration 1, ideal_n_lags: 8
# Iteration 2 finished
# Iteration 2, ideal_n_lags: 9
# Iteration 3 finished
# Iteration 3, ideal_n_lags: 8
# Iteration 4 finished
# Iteration 4, ideal_n_lags: 9
# Iteration 5 finished
# Iteration 5, ideal_n_lags: 8
# Iteration 6 finished
# Iteration 6, ideal_n_lags: 7
# Iteration 7 finished
# Iteration 7, ideal_n_lags: 8
# Iteration 8 finished
# Iteration 8, ideal_n_lags: 8
# Iteration 9 finished
# Iteration 9, ideal_n_lags: 8
# Iteration 10 finished
# Iteration 10, ideal_n_lags: 8
# Iteration 11 finished
# Iteration 11, ideal_n_lags: 10
# Iteration 12 finished
# Iteration 12, ideal_n_lags: 8
# Iteration 13 finished
# Iteration 13, ideal_n_lags: 9
# Iteration 14 finished
# Iteration 14, ideal_n_lags: 8
# Iteration 15 finished
# Iteration 15, ideal_n_lags: 8
# Iteration 16 finished
# Iteration 16, ideal_n_lags: 6
# Iteration 17 finished
# Iteration 17, ideal_n_lags: 8
# Iteration 18 finished
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# Copy the 'prediction_results' dictionary to invert the integration of the copy and set the index for predicted dates
prediction_results_processed = prediction_results.copy()
for symbol in prediction_results:
    pred_df = pd.DataFrame(prediction_results[symbol])
    pred_series = pred_df.mean(axis=1)
    pred_series = rets[symbol][-1] + pred_series.cumsum()

    future_dates = pd.date_range(start=rets.index.max().to_timestamp() + date_offset, periods=periods_to_forecast, freq=future_freq).to_period(period_freq)
    pred_series.index = future_dates

    prediction_results_processed[symbol] = pred_series

# %%
# Visualize the predictions of any stock
symbol = 'PFGRUPSURA.CL'
concat_df = pd.concat([rets[symbol][-50:], pd.DataFrame(prediction_results_processed[symbol], columns=[symbol])], axis=1)

concat_df.plot()
#prediction_results_processed[symbol].plot()
plt.grid(alpha=.4)
plt.title(symbol)
plt.show()

# %%
# Calculate the exptected annual returns for each stock
# Initialize an empty dictionary where the returns will be stored
expected_annualized_rets = {}

for symbol in prediction_results_processed:
    # Calculate the weighted average returns from the predictions and then annualize them
    # Uncomment the method of weighting for the averaging and annualization of the returns
    
    ### Raw predicted returns annualized
    # expected_annualized_returns = ((prediction_results_processed[symbol] + 1).prod()**(1/len(prediction_results_processed[symbol])))**(periods_per_year) - 1
    
    ### Linearly decaying weighted returns annualized
    # weight_indexes = np.array([i+1 for i in range(periods_to_forecast)])
    # linear_decay_w = (periods_to_forecast - weight_indexes + 1)/weight_indexes.sum()
    # expected_annualized_returns = (1 + np.sum(prediction_results_processed[symbol]*linear_decay_w))**periods_per_year - 1

    ### Exponentially decaying weighted returns annualized
    weight_indexes = np.array([i+1 for i in range(periods_to_forecast)])
    lambda_ = 0.2
    exponential_decay_w = np.exp(-lambda_*weight_indexes)/np.exp(-lambda_*weight_indexes).sum()
    expected_annualized_returns = (1 + np.sum(prediction_results_processed[symbol]*exponential_decay_w))**periods_per_year - 1

    expected_annualized_rets[symbol] = expected_annualized_returns

# %%
# Predictions of annualized returns for the VAR Bagging model
var_bagging_expected_annualized_rets = expected_annualized_rets
pd.Series(var_bagging_expected_annualized_rets)
# Out:
# BOGOTA.CL        0.022362
# BVC.CL          -0.066648
# CELSIA.CL        0.443168
# CEMARGOS.CL     -0.370310
# CIBEST.CL        0.066386
# CNEC.CL         -0.436195
# CONCONCRET.CL   -0.899379
# CORFICOLCF.CL   -0.324229
# ECOPETROL.CL     1.473181
# ENKA.CL         -0.400923
# ETB.CL           1.175438
# EXITO.CL         0.235140
# GEB.CL           0.547279
# GRUBOLIVAR.CL    0.086522
# GRUPOARGOS.CL   -0.681703
# GRUPOAVAL.CL    -0.089170
# GRUPOSURA.CL    -0.826752
# HCOLSEL.CL      -0.147250
# ICOLCAP.CL      -0.158889
# ISA.CL          -0.369499
# MINEROS.CL      -0.920655
# NUTRESA.CL       0.409383
# PFAVAL.CL       -0.164882
# PFCIBEST.CL     -0.364070
# PFCORFICOL.CL   -0.145334
# PFDAVVNDA.CL    -0.503370
# PFGRUPOARG.CL   -0.466026
# PFGRUPSURA.CL   -0.670206
# PROMIGAS.CL     -0.025839
# TERPEL.CL        0.251762
# AAPL             0.269931
# AGUAS-A.SN      -0.056298
# AMZN             0.605067
# ANDINA-B.SN      0.192268
# BAC             -0.188332
# ...

# %% [markdown]
# ## **Model 3: Transformer Neural Network**

# %% [markdown]
# ### **Generate the data**

# %%
data = rets[selected_stocks].values

# Prepare the data for training
def create_dataset(data, time_window=1):
    X, Y = [], []

    for i in range(len(data)-time_window):
        X.append(data[i:(i+time_window)])
        Y.append(data[i + time_window])
    return np.array(X), np.array(Y)

# time_window is derived from periods_per_year (one full year of history)
X, Y = create_dataset(data, time_window)

print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)

# %% [markdown]
# ### **Implement Positional Encoding**

# %%
# Positional encoding represents each time step's position in the sequence
class PositionalEncoding(nn.Module):
    def __init__(self, sequence_length, d_model):
        super().__init__()
        positions = np.arange(sequence_length)[:, np.newaxis]
        num_dims  = (d_model + 1) // 2
        div_term  = np.exp(np.arange(0, num_dims) * (-np.log(10000.0) / d_model))
        pos_enc   = np.zeros((sequence_length, d_model))
        pos_enc[:, 0::2] = np.sin(positions * div_term)
        pos_enc[:, 1::2] = np.cos(positions * div_term[:d_model // 2])
        self.register_buffer('pos_enc', torch.tensor(pos_enc, dtype=torch.float32).unsqueeze(0))

    def forward(self, x):
        return x + self.pos_enc

# %% [markdown]
# ### **Implement the Transformer Model**

# %%
# Full Transformer model: input projection → positional encoding →
# stacked encoder layers → global average pooling → output projection
class TransformerModel(nn.Module):
    def __init__(self, input_shape, head_size=128, num_heads=8, ff_dim=512, num_blocks=6, dropout=0.1):
        super().__init__()
        seq_len, num_features = input_shape
        d_model = 128  # Project features to a d_model divisible by num_heads

        self.input_proj = nn.Linear(num_features, d_model)
        self.pos_encoding = PositionalEncoding(seq_len, d_model)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=num_heads,
            dim_feedforward=ff_dim,
            dropout=dropout,
            batch_first=True,
            norm_first=True   # Pre-LN for more stable training
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_blocks)
        self.output_proj = nn.Linear(d_model, num_features)

    def forward(self, x):
        x = self.input_proj(x)
        x = self.pos_encoding(x)
        x = self.transformer_encoder(x)
        x = x.mean(dim=1)        # Global average pooling over the time dimension
        x = self.output_proj(x)
        return x

# %% [markdown]
# ### **Prepare training data and move to device**

# %%
input_shape = (time_window, X.shape[2])

# Move training data to the GPU (or CPU) once — reused across all training runs
X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
Y_tensor = torch.tensor(Y, dtype=torch.float32).to(device)
dataset  = TensorDataset(X_tensor, Y_tensor)

# %% [markdown]
# ### **Train the Model**

# %%
head_size             = 128
num_heads             = 8
ff_dim                = 512
num_transformer_blocks = 6
dropout               = 0.1

# Instantiate and summarise the model
model = TransformerModel(input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, dropout).to(device)
print(model)
print(f'\nTotal parameters: {sum(p.numel() for p in model.parameters()):,}')
print(f'Running on: {device}')
# Out:
# TransformerModel(
#   (input_proj): Linear(in_features=71, out_features=128, bias=True)
#   (pos_encoding): PositionalEncoding()
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-5): 6 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (output_proj): Linear(in_features=128, out_features=71, bias=True)
# )
#
# Total parameters: 1,208,007
# ...

# %%
# Number of independent training runs — predictions will be averaged across runs
# to reduce the effect of random weight initialisation
n_transformer_runs = 10

# %% [markdown]
# ### **Perform predictions**

# %%
# Generate the input for the prediction of future period

# Add a dummy array for the future period,
# so that the generate_dataset function will capture the latest observation in the last sequence
data_preds = data.copy()
data_preds = np.concatenate((data_preds, np.expand_dims(np.zeros_like(data_preds[-1]), axis=0)))

X_, Y_ = create_dataset(data_preds, time_window)

# %%
periods_to_forecast = 4
all_preds_runs = []

for run in range(n_transformer_runs):
    print(f'\n--- Transformer run {run + 1}/{n_transformer_runs} ---')

    # Fresh model + optimizer for each run
    run_model  = TransformerModel(input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, dropout).to(device)
    optimizer  = optim.Adam(run_model.parameters(), lr=1e-4)
    criterion  = nn.MSELoss()
    dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
    scaler     = torch.cuda.amp.GradScaler()  # Mixed-precision gradient scaler

    run_model.train()
    for epoch in range(50):
        for batch_x, batch_y in dataloader:
            optimizer.zero_grad()
            with torch.cuda.amp.autocast(dtype=torch.float16):  # FP16 for Tensor Core speed
                output = run_model(batch_x)
                loss   = criterion(output, batch_y)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

    # Forecast the next periods_to_forecast weeks autoregressively
    run_model.eval()
    run_preds   = []
    pred_inputs = torch.tensor(X_[-1], dtype=torch.float32).unsqueeze(0).to(device)

    with torch.no_grad():
        for _ in range(periods_to_forecast):
            with torch.cuda.amp.autocast(dtype=torch.float16):
                pred = run_model(pred_inputs)
            run_preds.append(pred[0].cpu().numpy())
            pred_inputs = torch.cat((pred_inputs[:, 1:, :], pred.unsqueeze(1)), dim=1)

    all_preds_runs.append(np.array(run_preds))

# Average across all runs to reduce the effect of random weight initialisation
preds = np.mean(all_preds_runs, axis=0)
print(f'\nPredictions averaged across {n_transformer_runs} runs.')
# Out:
# --- Transformer run 1/10 ---
# --- Transformer run 2/10 ---
# --- Transformer run 3/10 ---
# --- Transformer run 4/10 ---
# --- Transformer run 5/10 ---
# --- Transformer run 6/10 ---
# --- Transformer run 7/10 ---
# --- Transformer run 8/10 ---
# --- Transformer run 9/10 ---
# --- Transformer run 10/10 ---
# Predictions averaged across 10 runs.

# %%
preds_df = pd.DataFrame(preds, columns=selected_stocks)

future_dates = pd.date_range(start=rets.index.max().to_timestamp() + date_offset, periods=periods_to_forecast, freq=future_freq).to_period(period_freq)
preds_df = pd.DataFrame(preds, columns=selected_stocks, index=future_dates)

# %%
# Winsorise predicted weekly returns at the 1st-99th percentile of historical returns.
# Neural-network predictions can occasionally extrapolate far outside the training
# distribution; even a modestly wrong weekly figure compounds into an absurd annualised
# return (e.g. +8%/week -> +6 800 000%/year). Clipping at historical percentiles
# removes those extremes before they propagate through the compounding and annualisation
# steps, without discarding the relative signal across stocks.
lower_w = np.percentile(rets[selected_stocks].values, 1)
upper_w = np.percentile(rets[selected_stocks].values, 99)
preds_df = preds_df.clip(lower=lower_w, upper=upper_w)
print(f"Predictions winsorised to [{lower_w:.4f}, {upper_w:.4f}] (1st-99th pct of historical weekly returns).")
# Out:
# Predictions winsorised to [-0.1111, 0.1275] (1st-99th pct of historical weekly returns).

# %%
# Visualize the predictions of any stock
symbol = 'NVDA'#'PFGRUPSURA.CL'
concat_df = pd.concat([rets[symbol][-50:], preds_df[symbol]], axis=1)

concat_df.plot()
#prediction_results_processed[symbol].plot()
plt.grid(alpha=.4)
plt.title(symbol)
plt.show()

# %%
# Calculate the exptected annual returns for each stock
# Initialize an empty dictionary where the returns will be stored
expected_annualized_rets = {}

for symbol in preds_df.columns:
    # Calculate the weighted average returns from the predictions and then annualize them
    # Uncomment the method of weighting for the averaging and annualization of the returns
    
    ### Raw predicted returns annualized
    # expected_annualized_returns = ((prediction_results_processed[symbol] + 1).prod()**(1/len(prediction_results_processed[symbol])))**(periods_per_year) - 1
    
    ### Linearly decaying weighted returns annualized
    # weight_indexes = np.array([i+1 for i in range(periods_to_forecast)])
    # linear_decay_w = (periods_to_forecast - weight_indexes + 1)/weight_indexes.sum()
    # expected_annualized_returns = (1 + np.sum(prediction_results_processed[symbol]*linear_decay_w))**periods_per_year - 1

    ### Exponentially decaying weighted returns annualized
    weight_indexes = np.array([i+1 for i in range(periods_to_forecast)])
    lambda_ = 0.2
    exponential_decay_w = np.exp(-lambda_*weight_indexes)/np.exp(-lambda_*weight_indexes).sum()
    expected_annualized_returns = (1 + np.sum(preds_df[symbol]*exponential_decay_w))**periods_per_year - 1

    expected_annualized_rets[symbol] = expected_annualized_returns

# %%
# Predictions of annualized returns for the Transformer model
transformer_expected_annualized_rets = expected_annualized_rets
pd.Series(transformer_expected_annualized_rets).sort_values(ascending=False)
# Out:
# NVDA             1.401821
# PFCIBEST.CL      1.099385
# ENKA.CL          0.946817
# CONCONCRET.CL    0.942647
# CPAC             0.929815
# AAPL             0.902290
# PROMIGAS.CL      0.773457
# C                0.769846
# PFGRUPOARG.CL    0.747603
# PBR              0.703656
# ICOLCAP.CL       0.679370
# BOGOTA.CL        0.641819
# ITAUCL.SN        0.611343
# ISA.CL           0.607682
# JNJ              0.606733
# PFAVAL.CL        0.577734
# CEMARGOS.CL      0.531709
# CIBEST.CL        0.513778
# ANDINA-B.SN      0.474876
# ECOPETROL.CL     0.471034
# GRUPOARGOS.CL    0.459491
# SCCO             0.447879
# GRUPOAVAL.CL     0.425875
# SUAS.L           0.383665
# PFE              0.377923
# CSPX.L           0.354480
# CFMITNIPSA.SN    0.351347
# CELSIA.CL        0.336097
# COPEC.SN         0.305840
# VAPORES.SN       0.293239
# VOO              0.287788
# CHILE.SN         0.287414
# SPXS.L           0.244782
# EXITO.CL         0.218876
# ENELCHILE.SN     0.201743
# ...

# %%
# Compare returns of different models:
"""
pd.Series(historical_annualized_returns)
pd.Series(var_bagging_expected_annualized_rets)
pd.Series(transformer_expected_annualized_rets)
"""
# Out:
# '\npd.Series(historical_annualized_returns)\npd.Series(var_bagging_expected_annualized_rets)\npd.Series(transformer_expected_annualized_rets)\n'

# %%
# Uncomment the predictions of the model that was preferred
# expected_returns = historical_annualized_returns
# expected_returns = var_bagging_expected_annualized_rets
expected_returns = transformer_expected_annualized_rets

# %% [markdown]
# # **Covariance matrix estimation**

# %% [markdown]
# ## **Model 1: Ledoit-Wolf Shrinkage**

# %%
from sklearn.covariance import LedoitWolf

# Ledoit-Wolf shrinkage covariance
# Analytically optimal shrinkage estimator — significantly reduces estimation
# error vs. raw sample covariance, especially when n_stocks > n_observations.
ret_sample = rets[selected_stocks].iloc[-periods_per_year * 3:]
lw     = LedoitWolf().fit(ret_sample)
covmat = pd.DataFrame(lw.covariance_, index=selected_stocks, columns=selected_stocks)
covmat
# Out:
#                BOGOTA.CL    BVC.CL  CELSIA.CL  CEMARGOS.CL     CIBEST.CL  \
# BOGOTA.CL       0.001484 -0.000019   0.000316    -0.000128  2.792941e-04
# BVC.CL         -0.000019  0.002030   0.000399     0.000142  2.656138e-05
# CELSIA.CL       0.000316  0.000399   0.001874     0.000402  5.557416e-05
# CEMARGOS.CL    -0.000128  0.000142   0.000402     0.002515  1.924206e-04
# CIBEST.CL       0.000279  0.000027   0.000056     0.000192  1.854310e-03
# CNEC.CL        -0.000021 -0.000042  -0.000066     0.000070  8.983980e-05
# CONCONCRET.CL   0.000142 -0.000049   0.000199     0.000376  1.838851e-04
# CORFICOLCF.CL   0.000398  0.000100   0.000355     0.000210  4.422299e-04
# ECOPETROL.CL   -0.000026 -0.000050   0.000091     0.000165  1.363462e-04
# ENKA.CL        -0.000092  0.000251   0.000161     0.000131  1.652034e-04
# ETB.CL         -0.000040  0.000179   0.000337     0.000297  4.382734e-05
# EXITO.CL        0.000391  0.000068   0.000516    -0.000138  8.044069e-05
# ...

# %% [markdown]
# ## **Model 2: DCC-GARCH (commented out)**

# %%
# ── DCC-GARCH Covariance Estimator (commented out) ───────────────────────────
# Captures time-varying volatility clustering and dynamic cross-asset correlations.
# To enable: comment out the Ledoit-Wolf cell above, then uncomment this block.
# Requires: pip install arch
#
# from arch import arch_model
# from scipy.optimize import minimize
#
# def fit_dcc_garch(returns):
#     """
#     Fit DCC-GARCH(1,1) to a panel of returns and return the 1-step-ahead
#     conditional covariance matrix as a pandas DataFrame.
#
#     Steps:
#       1. Fit a univariate GARCH(1,1) to each stock to obtain standardised
#          residuals and last-period conditional volatilities.
#       2. Estimate DCC parameters a and b via maximum likelihood on the
#          standardised residuals.
#       3. Propagate the DCC recursion to get the final conditional correlation Rt.
#       4. Reconstruct the covariance: Cov = D @ Rt @ D  (D = diag of cond. vols).
#     """
#     tickers = returns.columns.tolist()
#     n, T    = len(tickers), len(returns)
#
#     # Step 1 — Univariate GARCH(1,1) per stock
#     print("Fitting univariate GARCH models...")
#     std_resids     = np.zeros((T, n))
#     cond_vols_last = np.zeros(n)
#     for i, ticker in enumerate(tickers):
#         am  = arch_model(returns[ticker] * 100, vol='GARCH', p=1, q=1,
#                          dist='Normal', rescale=False)
#         res = am.fit(disp='off')
#         # Reindex to input dates (GARCH drops the first observation internally)
#         sr = res.std_resid.reindex(returns.index).values
#         std_resids[:, i]  = sr
#         cond_vols_last[i] = res.conditional_volatility.iloc[-1] / 100
#
#     # Drop burn-in rows where any stock has NaN standardised residual
#     valid      = ~np.any(np.isnan(std_resids), axis=1)
#     std_resids = std_resids[valid]
#
#     # Step 2 — Unconditional correlation matrix (long-run DCC target Q̄)
#     Q_bar = (std_resids.T @ std_resids) / len(std_resids)
#
#     # Step 3 — Estimate DCC parameters via maximum likelihood
#     def dcc_loglik(params):
#         a, b = params
#         if a <= 0 or b <= 0 or a + b >= 1:
#             return 1e10
#         Qt, ll = Q_bar.copy(), 0.0
#         for eps_t in std_resids:
#             eps = eps_t.reshape(-1, 1)
#             Qt  = (1 - a - b) * Q_bar + a * (eps @ eps.T) + b * Qt
#             d   = np.sqrt(np.diag(Qt))
#             Rt  = Qt / np.outer(d, d)
#             try:
#                 cho    = np.linalg.cholesky(Rt)
#                 logdet = 2.0 * np.sum(np.log(np.diag(cho)))
#                 ll    += logdet + float(eps.T @ np.linalg.solve(Rt, eps))
#             except np.linalg.LinAlgError:
#                 return 1e10   # Rt not PSD — penalise
#         return ll
#
#     print("Estimating DCC parameters (takes a few minutes for large universes)...")
#     opt  = minimize(dcc_loglik, x0=[0.05, 0.93], method='Nelder-Mead',
#                     options={'maxiter': 1000, 'xatol': 1e-4, 'fatol': 1e-4})
#     a, b = opt.x
#     print(f"DCC parameters estimated — a: {a:.4f}, b: {b:.4f}")
#
#     # Step 4 — Recompute final conditional correlation Rt at the last time step
#     Qt = Q_bar.copy()
#     for eps_t in std_resids:
#         eps = eps_t.reshape(-1, 1)
#         Qt  = (1 - a - b) * Q_bar + a * (eps @ eps.T) + b * Qt
#     d  = np.sqrt(np.diag(Qt))
#     Rt = Qt / np.outer(d, d)
#
#     # Step 5 — Reconstruct conditional covariance matrix
#     D = np.diag(cond_vols_last)
#     return pd.DataFrame(D @ Rt @ D, index=tickers, columns=tickers)
#
# ret_sample = rets[selected_stocks].iloc[-periods_per_year * 5:]
# covmat = fit_dcc_garch(ret_sample)

# %% [markdown]
# # **Export predicted returns and covariance matrix**

# %%
pd.Series(expected_annualized_rets)[selected_stocks].to_csv('../temp_references/expected_returns.csv', header=None)

# %%
covmat.to_csv('../temp_references/expected_covmat.csv')
